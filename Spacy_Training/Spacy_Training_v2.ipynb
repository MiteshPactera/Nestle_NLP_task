# %% [markdown]
# https://manivannan-ai.medium.com/how-to-train-ner-with-custom-training-data-using-spacy-188e0e508c6

# %%
import spacy
import random
import re
import pandas as pd
pd.set_option('display.max_colwidth',None)

# %%
df = pd.read_csv('Generated_English_Queries_v3_without_keyword.csv',keep_default_na=False)
df.head()
# Out:
#                                English_Queries          Task Category  \
# 0   display Max Shipment  Cheese in year 2019?  Max Shipment   Cheese
# 1    generate Gross Sales  Candy in year 2019?   Gross Sales    Candy
# 2     generate Revenue  Gelatin in quarter Q4?       Revenue       NA
# 3  get Max Shipment  Aldi in quarter Q2 to Q4?  Max Shipment       NA
# 4           display Count  Bacon in year 2019?         Count       NA
#
#   Sub_Category Customer
# 0           NA       NA
# 1           NA       NA
# 2      Gelatin       NA
# 3           NA     Aldi
# 4        Bacon       NA

# %% [markdown]
# ### Change data to spacy training format

# %%
def return_index(sent,word):
    #return sent.index(word)
    match = re.search(word, sent)
    if match:
        return (match.start(), match.end())

# %%
c = 0
data = []
for index,row in df.iterrows():
#     if c == 50:
#         break
#     c += 1
    text = row['English_Queries']
    entities_lst = []
    
    if row['Task'] != 'NA':
        task = row['Task']
        index_start,index_end =return_index(text,task)
        entities_lst.append( (index_start,index_end,'Task') )
 
    if row['Category'] != 'NA':
        category = row['Category']
        index_start,index_end =return_index(text,category)
        entities_lst.append( (index_start,index_end,'Category') )
    
    if row['Sub_Category'] != 'NA':
        sub = row['Sub_Category']
        index_start,index_end =return_index(text,sub)
        entities_lst.append( (index_start,index_end,'Sub_Category') )
        
    if row['Customer'] != 'NA':
        cust = row['Customer']
        index_start,index_end =return_index(text,cust)
        entities_lst.append( (index_start,index_end,'Customer') )
        
    
    tuple_data = (text, {'entities' : entities_lst })
    data.append(tuple_data)

# %%
data
# Out:
# [('display Max Shipment  Cheese in year 2019?',
#   {'entities': [(8, 20, 'Task'), (22, 28, 'Category')]}),
#  ('generate Gross Sales  Candy in year 2019?',
#   {'entities': [(9, 20, 'Task'), (22, 27, 'Category')]}),
#  ('generate Revenue  Gelatin in quarter Q4?',
#   {'entities': [(9, 16, 'Task'), (18, 25, 'Sub_Category')]}),
#  ('get Max Shipment  Aldi in quarter Q2 to Q4?',
#   {'entities': [(4, 16, 'Task'), (18, 22, 'Customer')]}),
#  ('display Count  Bacon in year 2019?',
#   {'entities': [(8, 13, 'Task'), (15, 20, 'Sub_Category')]}),
#  ('fetch Net sales  Candy in year 2019?',
#   {'entities': [(6, 15, 'Task'), (17, 22, 'Category')]}),
#  ('generate Revenue  Creamers in quarter Q3?',
#   {'entities': [(9, 16, 'Task'), (18, 26, 'Sub_Category')]}),
#  ('get Net sales  Bars/Snacks in quarter Q2 to Q4?',
#   {'entities': [(4, 13, 'Task'), (15, 26, 'Sub_Category')]}),
#  ('fetch Count  Creamers in week Wk31?',
#   {'entities': [(6, 11, 'Task'), (13, 21, 'Sub_Category')]}),
#  ('generate Net sales  Meats in quarter Q1 to Q4?',
#   {'entities': [(9, 18, 'Task'), (20, 25, 'Category')]}),
#  ('fetch Revenue  Chocolate in week Wk1?',
#   {'entities': [(6, 13, 'Task'), (15, 24, 'Sub_Category')]}),
#  ('get Count  Juice in quarter Q1 to Q4?',
#   {'entities': [(4, 9, 'Task'), (11, 16, 'Sub_Category')]}),
#  ('fetch Top Line  Sauces in year 2019?',
#   {'entities': [(6, 14, 'Task'), (16, 22, 'Category')]}),
#  ('display Gross Sales  Ketchup in week Wk18 to Wk40?',
#   {'entities': [(8, 19, 'Task'), (21, 28, 'Sub_Category')]}),
#  ('display Max Shipment  Specialty Meats in year 2019?',
#   {'entities': [(8, 20, 'Task'), (22, 37, 'Sub_Category')]}),
#  ('fetch Bottom Line  Target in year 2019?',
#   {'entities': [(6, 17, 'Task'), (19, 25, 'Customer')]}),
#  ('display Count  Walmart in month Aug?',
#   {'entities': [(8, 13, 'Task'), (15, 22, 'Customer')]}),
#  ('fetch Count  Creamers in year 2019?',
#   {'entities': [(6, 11, 'Task'), (13, 21, 'Sub_Category')]}),
#  ('fetch Bottom Line  Albertsons/Safeway in year 2019?',
#   {'entities': [(6, 17, 'Task'), (19, 37, 'Customer')]}),
#  ('display Bottom Line  Sauces in week Wk15 to Wk34?',
#   {'entities': [(8, 19, 'Task'), (21, 27, 'Category')]}),
#  ('generate Revenue  Cheese in quarter Q3?',
#   {'entities': [(9, 16, 'Task'), (18, 24, 'Category')]}),
#  ('generate Top Line  Target in year 2019?',
#   {'entities': [(9, 17, 'Task'), (19, 25, 'Customer')]}),
#  ('fetch Gross Sales  Aldi in month Oct?',
#   {'entities': [(6, 17, 'Task'), (19, 23, 'Customer')]}),
#  ('display Net sales  Cheese in quarter Q1 to Q4?',
#   {'entities': [(8, 17, 'Task'), (19, 25, 'Category')]}),
#  ('fetch Bottom Line  Natural Cheese in month May?',
#   {'entities': [(6, 17, 'Task'), (19, 33, 'Sub_Category')]}),
#  ('display Bottom Line  UNIFI in quarter Q2 to Q4?',
#   {'entities': [(8, 19, 'Task'), (21, 26, 'Customer')]}),
#  ('fetch Max Shipment  Candy in month Sep?',
#   {'entities': [(6, 18, 'Task'), (20, 25, 'Category')]}),
#  ('display Top Line  Walmart in year 2019?',
#   {'entities': [(8, 16, 'Task'), (18, 25, 'Customer')]}),
#  ('fetch Top Line  Sauces in quarter Q2?',
#   {'entities': [(6, 14, 'Task'), (16, 22, 'Category')]}),
#  ('get Gross Sales  Mayonaise in month Apr to Sep?',
#   {'entities': [(4, 15, 'Task'), (17, 26, 'Sub_Category')]}),
#  ('get Gross Sales  Cold Cuts in quarter Q2?',
#   {'entities': [(4, 15, 'Task'), (17, 26, 'Sub_Category')]}),
#  ('display Count  Sauces in week Wk14 to Wk41?',
#   {'entities': [(8, 13, 'Task'), (15, 21, 'Category')]}),
#  ('generate Top Line  Specialty Meats in month Dec?',
#   {'entities': [(9, 17, 'Task'), (19, 34, 'Sub_Category')]}),
#  ('fetch Bottom Line  Shelf Stable in week Wk16 to Wk41?',
#   {'entities': [(6, 17, 'Task'), (19, 31, 'Sub_Category')]}),
#  ('fetch Top Line  Bars/Snacks in year 2019?',
#   {'entities': [(6, 14, 'Task'), (16, 27, 'Sub_Category')]}),
#  ('get Net sales  Natural Cheese in week Wk20 to Wk44?',
#   {'entities': [(4, 13, 'Task'), (15, 29, 'Sub_Category')]}),
#  ('fetch Count  Juice in week Wk13?',
#   {'entities': [(6, 11, 'Task'), (13, 18, 'Sub_Category')]}),
#  ('generate Net sales  Hot Dogs in week Wk3 to Wk48?',
#   {'entities': [(9, 18, 'Task'), (20, 28, 'Sub_Category')]}),
#  ('fetch Bottom Line  Meats in quarter Q3?',
#   {'entities': [(6, 17, 'Task'), (19, 24, 'Category')]}),
#  ('generate Bottom Line  UNIFI in quarter Q2 to Q4?',
#   {'entities': [(9, 20, 'Task'), (22, 27, 'Customer')]}),
#  ('get Top Line  Specialty Meats in year 2019?',
#   {'entities': [(4, 12, 'Task'), (14, 29, 'Sub_Category')]}),
#  ('generate Count  Breakfast in month Feb to Sep?',
#   {'entities': [(9, 14, 'Task'), (16, 25, 'Category')]}),
#  ('fetch Revenue  Walmart in week Wk50?',
#   {'entities': [(6, 13, 'Task'), (15, 22, 'Customer')]}),
#  ('fetch Top Line  UNIFI in week Wk2 to Wk47?',
#   {'entities': [(6, 14, 'Task'), (16, 21, 'Customer')]}),
#  ('display Gross Sales  Coffee in year 2019?',
#   {'entities': [(8, 19, 'Task'), (21, 27, 'Sub_Category')]}),
#  ('display Max Shipment  Tea in quarter Q1 to Q4?',
#   {'entities': [(8, 20, 'Task'), (22, 25, 'Sub_Category')]}),
#  ('fetch Top Line  Aldi in year 2019?',
#   {'entities': [(6, 14, 'Task'), (16, 20, 'Customer')]}),
#  ('display Bottom Line  Chocolate in week Wk18 to Wk39?',
#   {'entities': [(8, 19, 'Task'), (21, 30, 'Sub_Category')]}),
#  ('generate Bottom Line  Cheese in month Jul?',
#   {'entities': [(9, 20, 'Task'), (22, 28, 'Category')]}),
#  ('get Max Shipment  Kroger in quarter Q1 to Q4?',
#   {'entities': [(4, 16, 'Task'), (18, 24, 'Customer')]}),
#  ('display Count  Cheese in week Wk24?',
#   {'entities': [(8, 13, 'Task'), (15, 21, 'Category')]}),
#  ('display Bottom Line  Processed Cheese in week Wk11 to Wk40?',
#   {'entities': [(8, 19, 'Task'), (21, 37, 'Sub_Category')]}),
#  ('get Bottom Line  Cheese in quarter Q2?',
#   {'entities': [(4, 15, 'Task'), (17, 23, 'Category')]}),
#  ('get Max Shipment  Dollar General in quarter Q1 to Q4?',
#   {'entities': [(4, 16, 'Task'), (18, 32, 'Customer')]}),
#  ('get Net sales  Albertsons/Safeway in week Wk3?',
#   {'entities': [(4, 13, 'Task'), (15, 33, 'Customer')]}),
#  ('fetch Gross Sales  Albertsons/Safeway in month Feb to Sep?',
#   {'entities': [(6, 17, 'Task'), (19, 37, 'Customer')]}),
#  ('display Top Line  Specialty Meats in month Jun?',
#   {'entities': [(8, 16, 'Task'), (18, 33, 'Sub_Category')]}),
#  ('get Top Line  Candy in week Wk11 to Wk28?',
#   {'entities': [(4, 12, 'Task'), (14, 19, 'Category')]}),
#  ('display Net sales  Candy in week Wk16?',
#   {'entities': [(8, 17, 'Task'), (19, 24, 'Category')]}),
#  ('fetch Bottom Line  Tea in week Wk11 to Wk48?',
#   {'entities': [(6, 17, 'Task'), (19, 22, 'Sub_Category')]}),
#  ('display Count  Meats in quarter Q3?',
#   {'entities': [(8, 13, 'Task'), (15, 20, 'Category')]}),
#  ('get Bottom Line  Sauces in quarter Q2 to Q4?',
#   {'entities': [(4, 15, 'Task'), (17, 23, 'Category')]}),
#  ('generate Max Shipment  Aldi in quarter Q1?',
#   {'entities': [(9, 21, 'Task'), (23, 27, 'Customer')]}),
#  ('generate Count  Sauces in quarter Q1 to Q4?',
#   {'entities': [(9, 14, 'Task'), (16, 22, 'Category')]}),
#  ('fetch Net sales  Coffee in month Sep?',
#   {'entities': [(6, 15, 'Task'), (17, 23, 'Sub_Category')]}),
#  ('generate Gross Sales  Walmart in quarter Q2 to Q4?',
#   {'entities': [(9, 20, 'Task'), (22, 29, 'Customer')]}),
#  ('display Gross Sales  Breakfast in month Mar?',
#   {'entities': [(8, 19, 'Task'), (21, 30, 'Category')]}),
#  ('generate Net sales  UNIFI in month May to Oct?',
#   {'entities': [(9, 18, 'Task'), (20, 25, 'Customer')]}),
#  ('get Max Shipment  Chocolate in year 2019?',
#   {'entities': [(4, 16, 'Task'), (18, 27, 'Sub_Category')]}),
#  ('fetch Bottom Line  Meats in year 2019?',
#   {'entities': [(6, 17, 'Task'), (19, 24, 'Category')]}),
#  ('fetch Top Line  Costco in quarter Q3?',
#   {'entities': [(6, 14, 'Task'), (16, 22, 'Customer')]}),
#  ('fetch Top Line  Meats in week Wk12 to Wk27?',
#   {'entities': [(6, 14, 'Task'), (16, 21, 'Category')]}),
#  ('get Count  Chocolate in month May?',
#   {'entities': [(4, 9, 'Task'), (11, 20, 'Sub_Category')]}),
#  ('generate Top Line  Albertsons/Safeway in month Mar to Oct?',
#   {'entities': [(9, 17, 'Task'), (19, 37, 'Customer')]}),
#  ('get Revenue  Specialty Meats in week Wk20?',
#   {'entities': [(4, 11, 'Task'), (13, 28, 'Sub_Category')]}),
#  ('fetch Bottom Line  Costco in year 2019?',
#   {'entities': [(6, 17, 'Task'), (19, 25, 'Customer')]}),
#  ('generate Gross Sales  Ahold in year 2019?',
#   {'entities': [(9, 20, 'Task'), (22, 27, 'Customer')]}),
#  ('get Gross Sales  Enhancers in year 2019?',
#   {'entities': [(4, 15, 'Task'), (17, 26, 'Sub_Category')]}),
#  ('display Count  Shelf Stable in month Jan?',
#   {'entities': [(8, 13, 'Task'), (15, 27, 'Sub_Category')]}),
#  ('display Revenue  Tea in month Mar to Aug?',
#   {'entities': [(8, 15, 'Task'), (17, 20, 'Sub_Category')]}),
#  ('display Gross Sales  Juice in week Wk12?',
#   {'entities': [(8, 19, 'Task'), (21, 26, 'Sub_Category')]}),
#  ('fetch Net sales  Meats in quarter Q1 to Q4?',
#   {'entities': [(6, 15, 'Task'), (17, 22, 'Category')]}),
#  ('fetch Top Line  Meats in quarter Q2?',
#   {'entities': [(6, 14, 'Task'), (16, 21, 'Category')]}),
#  ('generate Count  Candy in year 2019?',
#   {'entities': [(9, 14, 'Task'), (16, 21, 'Category')]}),
#  ('display Count  Processed Cheese in month Nov?',
#   {'entities': [(8, 13, 'Task'), (15, 31, 'Sub_Category')]}),
#  ('display Net sales  Chocolate in quarter Q1 to Q4?',
#   {'entities': [(8, 17, 'Task'), (19, 28, 'Sub_Category')]}),
#  ('get Count  Ahold in month Feb?',
#   {'entities': [(4, 9, 'Task'), (11, 16, 'Customer')]}),
#  ('generate Bottom Line  Meats in month Apr to Aug?',
#   {'entities': [(9, 20, 'Task'), (22, 27, 'Category')]}),
#  ('generate Count  UNIFI in week Wk18?',
#   {'entities': [(9, 14, 'Task'), (16, 21, 'Customer')]}),
#  ('generate Count  Candy in quarter Q1 to Q4?',
#   {'entities': [(9, 14, 'Task'), (16, 21, 'Category')]}),
#  ('display Net sales  Cold Cuts in quarter Q1?',
#   {'entities': [(8, 17, 'Task'), (19, 28, 'Sub_Category')]}),
#  ('display Count  UNIFI in year 2019?',
#   {'entities': [(8, 13, 'Task'), (15, 20, 'Customer')]}),
#  ('get Count  Meats in month Aug?',
#   {'entities': [(4, 9, 'Task'), (11, 16, 'Category')]}),
#  ('display Max Shipment  Cheese in week Wk25 to Wk34?',
#   {'entities': [(8, 20, 'Task'), (22, 28, 'Category')]}),
#  ('generate Max Shipment  Gelatin in month Aug?',
#   {'entities': [(9, 21, 'Task'), (23, 30, 'Sub_Category')]}),
#  ('generate Top Line  Breakfast in week Wk7 to Wk49?',
#   {'entities': [(9, 17, 'Task'), (19, 28, 'Category')]}),
#  ('generate Revenue  Albertsons/Safeway in quarter Q3?',
#   {'entities': [(9, 16, 'Task'), (18, 36, 'Customer')]}),
#  ('display Gross Sales  Aldi in quarter Q2 to Q4?',
#   {'entities': [(8, 19, 'Task'), (21, 25, 'Customer')]}),
#  ('display Revenue  Breakfast in year 2019?',
#   {'entities': [(8, 15, 'Task'), (17, 26, 'Category')]}),
#  ('generate Net sales  Ahold in year 2019?',
#   {'entities': [(9, 18, 'Task'), (20, 25, 'Customer')]}),
#  ('fetch Top Line  Target in week Wk20?',
#   {'entities': [(6, 14, 'Task'), (16, 22, 'Customer')]}),
#  ('display Max Shipment  Kroger in quarter Q2 to Q4?',
#   {'entities': [(8, 20, 'Task'), (22, 28, 'Customer')]}),
#  ('fetch Net sales  Candy in month Nov?',
#   {'entities': [(6, 15, 'Task'), (17, 22, 'Category')]}),
#  ('generate Gross Sales  Gelatin in week Wk23 to Wk35?',
#   {'entities': [(9, 20, 'Task'), (22, 29, 'Sub_Category')]}),
#  ('display Revenue  Gelatin in year 2019?',
#   {'entities': [(8, 15, 'Task'), (17, 24, 'Sub_Category')]}),
#  ('get Bottom Line  Sauces in month May to Dec?',
#   {'entities': [(4, 15, 'Task'), (17, 23, 'Category')]}),
#  ('fetch Gross Sales  Meats in year 2019?',
#   {'entities': [(6, 17, 'Task'), (19, 24, 'Category')]}),
#  ('generate Revenue  Cheese in month Jun to Oct?',
#   {'entities': [(9, 16, 'Task'), (18, 24, 'Category')]}),
#  ('get Gross Sales  Candy in week Wk13?',
#   {'entities': [(4, 15, 'Task'), (17, 22, 'Category')]}),
#  ('get Bottom Line  Coffee in month May to Sep?',
#   {'entities': [(4, 15, 'Task'), (17, 23, 'Sub_Category')]}),
#  ('generate Top Line  Specialty Meats in week Wk49?',
#   {'entities': [(9, 17, 'Task'), (19, 34, 'Sub_Category')]}),
#  ('generate Top Line  Aldi in week Wk14 to Wk50?',
#   {'entities': [(9, 17, 'Task'), (19, 23, 'Customer')]}),
#  ('generate Top Line  Sauces in month Apr?',
#   {'entities': [(9, 17, 'Task'), (19, 25, 'Category')]}),
#  ('get Bottom Line  Caramels in year 2019?',
#   {'entities': [(4, 15, 'Task'), (17, 25, 'Sub_Category')]}),
#  ('get Max Shipment  Caramels in year 2019?',
#   {'entities': [(4, 16, 'Task'), (18, 26, 'Sub_Category')]}),
#  ('get Count  Sauces in year 2019?',
#   {'entities': [(4, 9, 'Task'), (11, 17, 'Category')]}),
#  ('generate Max Shipment  Cheese in month Jan?',
#   {'entities': [(9, 21, 'Task'), (23, 29, 'Category')]}),
#  ('display Bottom Line  UNIFI in month Apr to Sep?',
#   {'entities': [(8, 19, 'Task'), (21, 26, 'Customer')]}),
#  ('display Revenue  Sauces in month Jun?',
#   {'entities': [(8, 15, 'Task'), (17, 23, 'Category')]}),
#  ('fetch Net sales  Publix in week Wk15 to Wk29?',
#   {'entities': [(6, 15, 'Task'), (17, 23, 'Customer')]}),
#  ('display Top Line  Kroger in week Wk41?',
#   {'entities': [(8, 16, 'Task'), (18, 24, 'Customer')]}),
#  ('fetch Max Shipment  Ahold in month Feb to Dec?',
#   {'entities': [(6, 18, 'Task'), (20, 25, 'Customer')]}),
#  ('get Count  Sauces in month Dec?',
#   {'entities': [(4, 9, 'Task'), (11, 17, 'Category')]}),
#  ('get Revenue  Meats in week Wk24 to Wk35?',
#   {'entities': [(4, 11, 'Task'), (13, 18, 'Category')]}),
#  ('generate Gross Sales  Candy in week Wk32?',
#   {'entities': [(9, 20, 'Task'), (22, 27, 'Category')]}),
#  ('generate Count  Target in year 2019?',
#   {'entities': [(9, 14, 'Task'), (16, 22, 'Customer')]}),
#  ('display Revenue  Ahold in quarter Q4?',
#   {'entities': [(8, 15, 'Task'), (17, 22, 'Customer')]}),
#  ('display Max Shipment  Ahold in quarter Q2 to Q4?',
#   {'entities': [(8, 20, 'Task'), (22, 27, 'Customer')]}),
#  ('get Net sales  Aldi in year 2019?',
#   {'entities': [(4, 13, 'Task'), (15, 19, 'Customer')]}),
#  ('get Top Line  Natural Cheese in week Wk17 to Wk41?',
#   {'entities': [(4, 12, 'Task'), (14, 28, 'Sub_Category')]}),
#  ('fetch Count  Cheese in quarter Q4?',
#   {'entities': [(6, 11, 'Task'), (13, 19, 'Category')]}),
#  ('fetch Top Line  Kroger in year 2019?',
#   {'entities': [(6, 14, 'Task'), (16, 22, 'Customer')]}),
#  ('generate Revenue  Caramels in quarter Q3?',
#   {'entities': [(9, 16, 'Task'), (18, 26, 'Sub_Category')]}),
#  ('generate Bottom Line  Kroger in year 2019?',
#   {'entities': [(9, 20, 'Task'), (22, 28, 'Customer')]}),
#  ('display Max Shipment  Ketchup in year 2019?',
#   {'entities': [(8, 20, 'Task'), (22, 29, 'Sub_Category')]}),
#  ('get Count  Kroger in month Jun to Sep?',
#   {'entities': [(4, 9, 'Task'), (11, 17, 'Customer')]}),
#  ('display Revenue  Cheese in week Wk43?',
#   {'entities': [(8, 15, 'Task'), (17, 23, 'Category')]}),
#  ('generate Max Shipment  Meats in quarter Q2 to Q4?',
#   {'entities': [(9, 21, 'Task'), (23, 28, 'Category')]}),
#  ('generate Gross Sales  BBQ in year 2019?',
#   {'entities': [(9, 20, 'Task'), (22, 25, 'Sub_Category')]}),
#  ('display Max Shipment  Publix in quarter Q1 to Q4?',
#   {'entities': [(8, 20, 'Task'), (22, 28, 'Customer')]}),
#  ('generate Gross Sales  Caramels in week Wk44?',
#   {'entities': [(9, 20, 'Task'), (22, 30, 'Sub_Category')]}),
#  ('generate Max Shipment  Breakfast in week Wk17 to Wk52?',
#   {'entities': [(9, 21, 'Task'), (23, 32, 'Category')]}),
#  ('get Count  Cold Cuts in week Wk3?',
#   {'entities': [(4, 9, 'Task'), (11, 20, 'Sub_Category')]}),
#  ('get Bottom Line  Dollar General in week Wk25 to Wk39?',
#   {'entities': [(4, 15, 'Task'), (17, 31, 'Customer')]}),
#  ('generate Gross Sales  Dollar General in month Feb?',
#   {'entities': [(9, 20, 'Task'), (22, 36, 'Customer')]}),
#  ('display Bottom Line  Breakfast in quarter Q2 to Q4?',
#   {'entities': [(8, 19, 'Task'), (21, 30, 'Category')]}),
#  ('get Gross Sales  Natural Cheese in week Wk37?',
#   {'entities': [(4, 15, 'Task'), (17, 31, 'Sub_Category')]}),
#  ('generate Net sales  Amazon in year 2019?',
#   {'entities': [(9, 18, 'Task'), (20, 26, 'Customer')]}),
#  ('display Top Line  Candy in year 2019?',
#   {'entities': [(8, 16, 'Task'), (18, 23, 'Category')]}),
#  ('get Revenue  Enhancers in quarter Q1 to Q4?',
#   {'entities': [(4, 11, 'Task'), (13, 22, 'Sub_Category')]}),
#  ('get Max Shipment  Juice in year 2019?',
#   {'entities': [(4, 16, 'Task'), (18, 23, 'Sub_Category')]}),
#  ('get Net sales  Amazon in year 2019?',
#   {'entities': [(4, 13, 'Task'), (15, 21, 'Customer')]}),
#  ('display Gross Sales  Sauces in week Wk6?',
#   {'entities': [(8, 19, 'Task'), (21, 27, 'Category')]}),
#  ('generate Top Line  Aldi in week Wk21 to Wk40?',
#   {'entities': [(9, 17, 'Task'), (19, 23, 'Customer')]}),
#  ('display Count  Bars/Snacks in year 2019?',
#   {'entities': [(8, 13, 'Task'), (15, 26, 'Sub_Category')]}),
#  ('get Revenue  Processed Cheese in month Feb to Oct?',
#   {'entities': [(4, 11, 'Task'), (13, 29, 'Sub_Category')]}),
#  ('generate Count  Ahold in week Wk9?',
#   {'entities': [(9, 14, 'Task'), (16, 21, 'Customer')]}),
#  ('fetch Net sales  Ahold in year 2019?',
#   {'entities': [(6, 15, 'Task'), (17, 22, 'Customer')]}),
#  ('fetch Gross Sales  Creamers in month Apr?',
#   {'entities': [(6, 17, 'Task'), (19, 27, 'Sub_Category')]}),
#  ('fetch Count  Hot Dogs in month May to Sep?',
#   {'entities': [(6, 11, 'Task'), (13, 21, 'Sub_Category')]}),
#  ('get Bottom Line  Candy in year 2019?',
#   {'entities': [(4, 15, 'Task'), (17, 22, 'Category')]}),
#  ('display Count  Walmart in quarter Q2 to Q4?',
#   {'entities': [(8, 13, 'Task'), (15, 22, 'Customer')]}),
#  ('generate Net sales  Caramels in year 2019?',
#   {'entities': [(9, 18, 'Task'), (20, 28, 'Sub_Category')]}),
#  ('fetch Gross Sales  Hard in quarter Q1 to Q4?',
#   {'entities': [(6, 17, 'Task'), (19, 23, 'Sub_Category')]}),
#  ('display Gross Sales  Creamers in year 2019?',
#   {'entities': [(8, 19, 'Task'), (21, 29, 'Sub_Category')]}),
#  ('generate Net sales  Mayonaise in month Apr to Aug?',
#   {'entities': [(9, 18, 'Task'), (20, 29, 'Sub_Category')]}),
#  ('display Count  Albertsons/Safeway in month Mar?',
#   {'entities': [(8, 13, 'Task'), (15, 33, 'Customer')]}),
#  ('display Bottom Line  Kroger in year 2019?',
#   {'entities': [(8, 19, 'Task'), (21, 27, 'Customer')]}),
#  ('display Count  Sauces in year 2019?',
#   {'entities': [(8, 13, 'Task'), (15, 21, 'Category')]}),
#  ('fetch Count  Costco in month Apr to Sep?',
#   {'entities': [(6, 11, 'Task'), (13, 19, 'Customer')]}),
#  ('display Top Line  Albertsons/Safeway in year 2019?',
#   {'entities': [(8, 16, 'Task'), (18, 36, 'Customer')]}),
#  ('generate Net sales  Ahold in week Wk12 to Wk36?',
#   {'entities': [(9, 18, 'Task'), (20, 25, 'Customer')]}),
#  ('fetch Max Shipment  Amazon in week Wk20?',
#   {'entities': [(6, 18, 'Task'), (20, 26, 'Customer')]}),
#  ('fetch Max Shipment  Hard in year 2019?',
#   {'entities': [(6, 18, 'Task'), (20, 24, 'Sub_Category')]}),
#  ('display Net sales  UNIFI in quarter Q2?',
#   {'entities': [(8, 17, 'Task'), (19, 24, 'Customer')]}),
#  ('display Top Line  Gelatin in week Wk1 to Wk43?',
#   {'entities': [(8, 16, 'Task'), (18, 25, 'Sub_Category')]}),
#  ('get Net sales  Ahold in week Wk2?',
#   {'entities': [(4, 13, 'Task'), (15, 20, 'Customer')]}),
#  ('get Max Shipment  Creamers in month Mar to Sep?',
#   {'entities': [(4, 16, 'Task'), (18, 26, 'Sub_Category')]}),
#  ('get Bottom Line  Amazon in month Jan?',
#   {'entities': [(4, 15, 'Task'), (17, 23, 'Customer')]}),
#  ('display Max Shipment  BBQ in week Wk25 to Wk30?',
#   {'entities': [(8, 20, 'Task'), (22, 25, 'Sub_Category')]}),
#  ('get Gross Sales  UNIFI in quarter Q1?',
#   {'entities': [(4, 15, 'Task'), (17, 22, 'Customer')]}),
#  ('fetch Top Line  Meats in month Mar to Nov?',
#   {'entities': [(6, 14, 'Task'), (16, 21, 'Category')]}),
#  ('get Net sales  Sauces in month Mar?',
#   {'entities': [(4, 13, 'Task'), (15, 21, 'Category')]}),
#  ('generate Revenue  Sauces in year 2019?',
#   {'entities': [(9, 16, 'Task'), (18, 24, 'Category')]}),
#  ('get Gross Sales  Bars/Snacks in month Sep?',
#   {'entities': [(4, 15, 'Task'), (17, 28, 'Sub_Category')]}),
#  ('fetch Revenue  Cheese in year 2019?',
#   {'entities': [(6, 13, 'Task'), (15, 21, 'Category')]}),
#  ('display Bottom Line  UNIFI in month Oct?',
#   {'entities': [(8, 19, 'Task'), (21, 26, 'Customer')]}),
#  ('get Count  Hot Dogs in week Wk4 to Wk36?',
#   {'entities': [(4, 9, 'Task'), (11, 19, 'Sub_Category')]}),
#  ('display Top Line  Tea in quarter Q1?',
#   {'entities': [(8, 16, 'Task'), (18, 21, 'Sub_Category')]}),
#  ('get Revenue  Meats in year 2019?',
#   {'entities': [(4, 11, 'Task'), (13, 18, 'Category')]}),
#  ('display Count  Meats in year 2019?',
#   {'entities': [(8, 13, 'Task'), (15, 20, 'Category')]}),
#  ('fetch Gross Sales  Amazon in quarter Q2 to Q4?',
#   {'entities': [(6, 17, 'Task'), (19, 25, 'Customer')]}),
#  ('display Max Shipment  Walmart in year 2019?',
#   {'entities': [(8, 20, 'Task'), (22, 29, 'Customer')]}),
#  ('fetch Net sales  Hot Dogs in month Mar to Nov?',
#   {'entities': [(6, 15, 'Task'), (17, 25, 'Sub_Category')]}),
#  ('fetch Gross Sales  Candy in year 2019?',
#   {'entities': [(6, 17, 'Task'), (19, 24, 'Category')]}),
#  ('display Top Line  Breakfast in week Wk21 to Wk47?',
#   {'entities': [(8, 16, 'Task'), (18, 27, 'Category')]}),
#  ('display Count  Albertsons/Safeway in quarter Q4?',
#   {'entities': [(8, 13, 'Task'), (15, 33, 'Customer')]}),
#  ('display Max Shipment  Kroger in quarter Q1 to Q4?',
#   {'entities': [(8, 20, 'Task'), (22, 28, 'Customer')]}),
#  ('fetch Net sales  All others in week Wk33?',
#   {'entities': [(6, 15, 'Task'), (17, 27, 'Sub_Category')]}),
#  ('display Bottom Line  Grated in year 2019?',
#   {'entities': [(8, 19, 'Task'), (21, 27, 'Sub_Category')]}),
#  ('display Gross Sales  Meats in quarter Q1?',
#   {'entities': [(8, 19, 'Task'), (21, 26, 'Category')]}),
#  ('get Gross Sales  Meats in quarter Q1 to Q4?',
#   {'entities': [(4, 15, 'Task'), (17, 22, 'Category')]}),
#  ('fetch Gross Sales  Specialty Meats in week Wk48?',
#   {'entities': [(6, 17, 'Task'), (19, 34, 'Sub_Category')]}),
#  ('get Revenue  All others in week Wk8 to Wk41?',
#   {'entities': [(4, 11, 'Task'), (13, 23, 'Sub_Category')]}),
#  ('fetch Max Shipment  Ahold in year 2019?',
#   {'entities': [(6, 18, 'Task'), (20, 25, 'Customer')]}),
#  ('generate Top Line  Kroger in week Wk14 to Wk39?',
#   {'entities': [(9, 17, 'Task'), (19, 25, 'Customer')]}),
#  ('display Revenue  Walmart in week Wk41?',
#   {'entities': [(8, 15, 'Task'), (17, 24, 'Customer')]}),
#  ('fetch Revenue  Meats in quarter Q2 to Q4?',
#   {'entities': [(6, 13, 'Task'), (15, 20, 'Category')]}),
#  ('get Count  Cheese in year 2019?',
#   {'entities': [(4, 9, 'Task'), (11, 17, 'Category')]}),
#  ('fetch Max Shipment  Sauces in year 2019?',
#   {'entities': [(6, 18, 'Task'), (20, 26, 'Category')]}),
#  ('generate Bottom Line  Natural Cheese in week Wk15?',
#   {'entities': [(9, 20, 'Task'), (22, 36, 'Sub_Category')]}),
#  ('fetch Top Line  Aldi in quarter Q2 to Q4?',
#   {'entities': [(6, 14, 'Task'), (16, 20, 'Customer')]}),
#  ('fetch Count  UNIFI in quarter Q2?',
#   {'entities': [(6, 11, 'Task'), (13, 18, 'Customer')]}),
#  ('display Bottom Line  Sauces in year 2019?',
#   {'entities': [(8, 19, 'Task'), (21, 27, 'Category')]}),
#  ('display Gross Sales  Dollar General in quarter Q1?',
#   {'entities': [(8, 19, 'Task'), (21, 35, 'Customer')]}),
#  ('display Max Shipment  Walmart in year 2019?',
#   {'entities': [(8, 20, 'Task'), (22, 29, 'Customer')]}),
#  ('generate Gross Sales  UNIFI in quarter Q3?',
#   {'entities': [(9, 20, 'Task'), (22, 27, 'Customer')]}),
#  ('fetch Count  Mayonaise in year 2019?',
#   {'entities': [(6, 11, 'Task'), (13, 22, 'Sub_Category')]}),
#  ('generate Gross Sales  Kroger in year 2019?',
#   {'entities': [(9, 20, 'Task'), (22, 28, 'Customer')]}),
#  ('generate Gross Sales  Ahold in quarter Q1 to Q4?',
#   {'entities': [(9, 20, 'Task'), (22, 27, 'Customer')]}),
#  ('fetch Gross Sales  Target in week Wk42?',
#   {'entities': [(6, 17, 'Task'), (19, 25, 'Customer')]}),
#  ('fetch Revenue  Juice in year 2019?',
#   {'entities': [(6, 13, 'Task'), (15, 20, 'Sub_Category')]}),
#  ('get Bottom Line  Publix in quarter Q3?',
#   {'entities': [(4, 15, 'Task'), (17, 23, 'Customer')]}),
#  ('generate Max Shipment  Meats in year 2019?',
#   {'entities': [(9, 21, 'Task'), (23, 28, 'Category')]}),
#  ('display Top Line  Publix in week Wk7?',
#   {'entities': [(8, 16, 'Task'), (18, 24, 'Customer')]}),
#  ('generate Top Line  Walmart in quarter Q2 to Q4?',
#   {'entities': [(9, 17, 'Task'), (19, 26, 'Customer')]}),
#  ('display Gross Sales  Candy in week Wk19?',
#   {'entities': [(8, 19, 'Task'), (21, 26, 'Category')]}),
#  ('display Bottom Line  Candy in year 2019?',
#   {'entities': [(8, 19, 'Task'), (21, 26, 'Category')]}),
#  ('fetch Max Shipment  Ahold in year 2019?',
#   {'entities': [(6, 18, 'Task'), (20, 25, 'Customer')]}),
#  ('generate Gross Sales  Breakfast in month Jan to Aug?',
#   {'entities': [(9, 20, 'Task'), (22, 31, 'Category')]}),
#  ('fetch Gross Sales  Bacon in year 2019?',
#   {'entities': [(6, 17, 'Task'), (19, 24, 'Sub_Category')]}),
#  ('get Gross Sales  Candy in month Mar to Oct?',
#   {'entities': [(4, 15, 'Task'), (17, 22, 'Category')]}),
#  ('display Gross Sales  UNIFI in year 2019?',
#   {'entities': [(8, 19, 'Task'), (21, 26, 'Customer')]}),
#  ('fetch Count  Dollar General in month Jun to Aug?',
#   {'entities': [(6, 11, 'Task'), (13, 27, 'Customer')]}),
#  ('get Bottom Line  Shelf Stable in quarter Q4?',
#   {'entities': [(4, 15, 'Task'), (17, 29, 'Sub_Category')]}),
#  ('display Bottom Line  Publix in week Wk9 to Wk42?',
#   {'entities': [(8, 19, 'Task'), (21, 27, 'Customer')]}),
#  ('fetch Gross Sales  Coffee in year 2019?',
#   {'entities': [(6, 17, 'Task'), (19, 25, 'Sub_Category')]}),
#  ('display Revenue  Ketchup in quarter Q1 to Q4?',
#   {'entities': [(8, 15, 'Task'), (17, 24, 'Sub_Category')]}),
#  ('get Bottom Line  Walmart in quarter Q3?',
#   {'entities': [(4, 15, 'Task'), (17, 24, 'Customer')]}),
#  ('generate Net sales  Processed Cheese in month Mar to Aug?',
#   {'entities': [(9, 18, 'Task'), (20, 36, 'Sub_Category')]}),
#  ('generate Gross Sales  Breakfast in quarter Q2?',
#   {'entities': [(9, 20, 'Task'), (22, 31, 'Category')]}),
#  ('fetch Revenue  Cheese in month Feb to Aug?',
#   {'entities': [(6, 13, 'Task'), (15, 21, 'Category')]}),
#  ('generate Bottom Line  Breakfast in month Nov?',
#   {'entities': [(9, 20, 'Task'), (22, 31, 'Category')]}),
#  ('fetch Max Shipment  Bars/Snacks in year 2019?',
#   {'entities': [(6, 18, 'Task'), (20, 31, 'Sub_Category')]}),
#  ('display Gross Sales  Bars/Snacks in year 2019?',
#   {'entities': [(8, 19, 'Task'), (21, 32, 'Sub_Category')]}),
#  ('fetch Net sales  UNIFI in week Wk14 to Wk46?',
#   {'entities': [(6, 15, 'Task'), (17, 22, 'Customer')]}),
#  ('get Bottom Line  Hot Dogs in quarter Q2?',
#   {'entities': [(4, 15, 'Task'), (17, 25, 'Sub_Category')]}),
#  ('fetch Gross Sales  Target in quarter Q2 to Q4?',
#   {'entities': [(6, 17, 'Task'), (19, 25, 'Customer')]}),
#  ('get Count  Aldi in month Jan?',
#   {'entities': [(4, 9, 'Task'), (11, 15, 'Customer')]}),
#  ('get Top Line  Sauces in month Apr to Nov?',
#   {'entities': [(4, 12, 'Task'), (14, 20, 'Category')]}),
#  ('generate Count  Ahold in quarter Q4?',
#   {'entities': [(9, 14, 'Task'), (16, 21, 'Customer')]}),
#  ('get Count  Creamers in month Mar to Sep?',
#   {'entities': [(4, 9, 'Task'), (11, 19, 'Sub_Category')]}),
#  ('generate Revenue  Amazon in week Wk12?',
#   {'entities': [(9, 16, 'Task'), (18, 24, 'Customer')]}),
#  ('display Bottom Line  Hot Dogs in quarter Q2 to Q4?',
#   {'entities': [(8, 19, 'Task'), (21, 29, 'Sub_Category')]}),
#  ('get Count  Coffee in week Wk31?',
#   {'entities': [(4, 9, 'Task'), (11, 17, 'Sub_Category')]}),
#  ('get Bottom Line  UNIFI in week Wk7 to Wk27?',
#   {'entities': [(4, 15, 'Task'), (17, 22, 'Customer')]}),
#  ('generate Gross Sales  Breakfast in month Dec?',
#   {'entities': [(9, 20, 'Task'), (22, 31, 'Category')]}),
#  ('fetch Top Line  Natural Cheese in quarter Q2 to Q4?',
#   {'entities': [(6, 14, 'Task'), (16, 30, 'Sub_Category')]}),
#  ('display Net sales  Breakfast in week Wk30?',
#   {'entities': [(8, 17, 'Task'), (19, 28, 'Category')]}),
#  ('fetch Max Shipment  Meats in year 2019?',
#   {'entities': [(6, 18, 'Task'), (20, 25, 'Category')]}),
#  ('display Top Line  Caramels in quarter Q4?',
#   {'entities': [(8, 16, 'Task'), (18, 26, 'Sub_Category')]}),
#  ('display Count  Bacon in quarter Q1 to Q4?',
#   {'entities': [(8, 13, 'Task'), (15, 20, 'Sub_Category')]}),
#  ('get Gross Sales  Costco in month May?',
#   {'entities': [(4, 15, 'Task'), (17, 23, 'Customer')]}),
#  ('get Bottom Line  Dollar General in week Wk17 to Wk28?',
#   {'entities': [(4, 15, 'Task'), (17, 31, 'Customer')]}),
#  ('get Bottom Line  Hard in month Oct?',
#   {'entities': [(4, 15, 'Task'), (17, 21, 'Sub_Category')]}),
#  ('generate Revenue  UNIFI in quarter Q2 to Q4?',
#   {'entities': [(9, 16, 'Task'), (18, 23, 'Customer')]}),
#  ('get Top Line  Grated in quarter Q2?',
#   {'entities': [(4, 12, 'Task'), (14, 20, 'Sub_Category')]}),
#  ('fetch Net sales  Hard in month Apr to Dec?',
#   {'entities': [(6, 15, 'Task'), (17, 21, 'Sub_Category')]}),
#  ('fetch Max Shipment  Aldi in year 2019?',
#   {'entities': [(6, 18, 'Task'), (20, 24, 'Customer')]}),
#  ('generate Gross Sales  Candy in month May to Nov?',
#   {'entities': [(9, 20, 'Task'), (22, 27, 'Category')]}),
#  ('get Revenue  Sauces in quarter Q1?',
#   {'entities': [(4, 11, 'Task'), (13, 19, 'Category')]}),
#  ('generate Net sales  Costco in quarter Q1 to Q4?',
#   {'entities': [(9, 18, 'Task'), (20, 26, 'Customer')]}),
#  ('generate Net sales  Aldi in week Wk19?',
#   {'entities': [(9, 18, 'Task'), (20, 24, 'Customer')]}),
#  ('get Net sales  Enhancers in year 2019?',
#   {'entities': [(4, 13, 'Task'), (15, 24, 'Sub_Category')]}),
#  ('get Gross Sales  Breakfast in quarter Q4?',
#   {'entities': [(4, 15, 'Task'), (17, 26, 'Category')]}),
#  ('get Count  Sauces in month Apr to Oct?',
#   {'entities': [(4, 9, 'Task'), (11, 17, 'Category')]}),
#  ('display Bottom Line  Chocolate in quarter Q1?',
#   {'entities': [(8, 19, 'Task'), (21, 30, 'Sub_Category')]}),
#  ('fetch Revenue  Breakfast in year 2019?',
#   {'entities': [(6, 13, 'Task'), (15, 24, 'Category')]}),
#  ('display Revenue  Albertsons/Safeway in month Jun?',
#   {'entities': [(8, 15, 'Task'), (17, 35, 'Customer')]}),
#  ('display Top Line  Kroger in year 2019?',
#   {'entities': [(8, 16, 'Task'), (18, 24, 'Customer')]}),
#  ('get Bottom Line  Caramels in year 2019?',
#   {'entities': [(4, 15, 'Task'), (17, 25, 'Sub_Category')]}),
#  ('get Top Line  Cheese in quarter Q1 to Q4?',
#   {'entities': [(4, 12, 'Task'), (14, 20, 'Category')]}),
#  ('generate Revenue  Sauces in month Mar?',
#   {'entities': [(9, 16, 'Task'), (18, 24, 'Category')]}),
#  ('generate Count  UNIFI in month Jun to Aug?',
#   {'entities': [(9, 14, 'Task'), (16, 21, 'Customer')]}),
#  ('generate Gross Sales  Natural Cheese in year 2019?',
#   {'entities': [(9, 20, 'Task'), (22, 36, 'Sub_Category')]}),
#  ('fetch Net sales  Specialty Meats in quarter Q1 to Q4?',
#   {'entities': [(6, 15, 'Task'), (17, 32, 'Sub_Category')]}),
#  ('display Count  Tea in week Wk5?',
#   {'entities': [(8, 13, 'Task'), (15, 18, 'Sub_Category')]}),
#  ('generate Net sales  Chocolate in quarter Q1 to Q4?',
#   {'entities': [(9, 18, 'Task'), (20, 29, 'Sub_Category')]}),
#  ('get Count  Walmart in week Wk52?',
#   {'entities': [(4, 9, 'Task'), (11, 18, 'Customer')]}),
#  ('display Max Shipment  All others in week Wk2 to Wk27?',
#   {'entities': [(8, 20, 'Task'), (22, 32, 'Sub_Category')]}),
#  ('generate Bottom Line  Publix in year 2019?',
#   {'entities': [(9, 20, 'Task'), (22, 28, 'Customer')]}),
#  ('display Revenue  Enhancers in quarter Q1 to Q4?',
#   {'entities': [(8, 15, 'Task'), (17, 26, 'Sub_Category')]}),
#  ('fetch Net sales  Candy in week Wk8?',
#   {'entities': [(6, 15, 'Task'), (17, 22, 'Category')]}),
#  ('fetch Gross Sales  Target in month Apr to Sep?',
#   {'entities': [(6, 17, 'Task'), (19, 25, 'Customer')]}),
#  ('fetch Net sales  Meats in month Feb?',
#   {'entities': [(6, 15, 'Task'), (17, 22, 'Category')]}),
#  ('display Gross Sales  Publix in month Apr to Oct?',
#   {'entities': [(8, 19, 'Task'), (21, 27, 'Customer')]}),
#  ('display Net sales  Meats in year 2019?',
#   {'entities': [(8, 17, 'Task'), (19, 24, 'Category')]}),
#  ('fetch Revenue  Juice in quarter Q1 to Q4?',
#   {'entities': [(6, 13, 'Task'), (15, 20, 'Sub_Category')]}),
#  ('display Revenue  Publix in year 2019?',
#   {'entities': [(8, 15, 'Task'), (17, 23, 'Customer')]}),
#  ('generate Revenue  Cheese in month Mar to Oct?',
#   {'entities': [(9, 16, 'Task'), (18, 24, 'Category')]}),
#  ('get Count  Albertsons/Safeway in month Dec?',
#   {'entities': [(4, 9, 'Task'), (11, 29, 'Customer')]}),
#  ('get Top Line  Sauces in week Wk20 to Wk33?',
#   {'entities': [(4, 12, 'Task'), (14, 20, 'Category')]}),
#  ('generate Gross Sales  Target in month Dec?',
#   {'entities': [(9, 20, 'Task'), (22, 28, 'Customer')]}),
#  ('generate Bottom Line  Natural Cheese in month May to Oct?',
#   {'entities': [(9, 20, 'Task'), (22, 36, 'Sub_Category')]}),
#  ('get Top Line  Costco in quarter Q2?',
#   {'entities': [(4, 12, 'Task'), (14, 20, 'Customer')]}),
#  ('get Revenue  Bars/Snacks in quarter Q1 to Q4?',
#   {'entities': [(4, 11, 'Task'), (13, 24, 'Sub_Category')]}),
#  ('generate Max Shipment  Grated in week Wk51?',
#   {'entities': [(9, 21, 'Task'), (23, 29, 'Sub_Category')]}),
#  ('generate Count  Chocolate in month Mar to Sep?',
#   {'entities': [(9, 14, 'Task'), (16, 25, 'Sub_Category')]}),
#  ('get Net sales  Cold Cuts in quarter Q1?',
#   {'entities': [(4, 13, 'Task'), (15, 24, 'Sub_Category')]}),
#  ('get Top Line  Shelf Stable in year 2019?',
#   {'entities': [(4, 12, 'Task'), (14, 26, 'Sub_Category')]}),
#  ('get Bottom Line  Coffee in month Feb?',
#   {'entities': [(4, 15, 'Task'), (17, 23, 'Sub_Category')]}),
#  ('generate Net sales  Tea in quarter Q1 to Q4?',
#   {'entities': [(9, 18, 'Task'), (20, 23, 'Sub_Category')]}),
#  ('display Revenue  Breakfast in year 2019?',
#   {'entities': [(8, 15, 'Task'), (17, 26, 'Category')]}),
#  ('get Max Shipment  Dollar General in quarter Q2 to Q4?',
#   {'entities': [(4, 16, 'Task'), (18, 32, 'Customer')]}),
#  ('get Bottom Line  Breakfast in year 2019?',
#   {'entities': [(4, 15, 'Task'), (17, 26, 'Category')]}),
#  ('display Bottom Line  Meats in week Wk11 to Wk50?',
#   {'entities': [(8, 19, 'Task'), (21, 26, 'Category')]}),
#  ('display Bottom Line  Amazon in quarter Q2?',
#   {'entities': [(8, 19, 'Task'), (21, 27, 'Customer')]}),
#  ('get Count  Publix in year 2019?',
#   {'entities': [(4, 9, 'Task'), (11, 17, 'Customer')]}),
#  ('generate Top Line  Chocolate in week Wk7?',
#   {'entities': [(9, 17, 'Task'), (19, 28, 'Sub_Category')]}),
#  ('fetch Max Shipment  Candy in quarter Q2 to Q4?',
#   {'entities': [(6, 18, 'Task'), (20, 25, 'Category')]}),
#  ('generate Top Line  Meats in month Jun?',
#   {'entities': [(9, 17, 'Task'), (19, 24, 'Category')]}),
#  ('display Gross Sales  Hot Dogs in quarter Q2 to Q4?',
#   {'entities': [(8, 19, 'Task'), (21, 29, 'Sub_Category')]}),
#  ('get Gross Sales  Sauces in month Jan?',
#   {'entities': [(4, 15, 'Task'), (17, 23, 'Category')]}),
#  ('fetch Count  Caramels in week Wk23 to Wk36?',
#   {'entities': [(6, 11, 'Task'), (13, 21, 'Sub_Category')]}),
#  ('generate Net sales  Cold Cuts in month Dec?',
#   {'entities': [(9, 18, 'Task'), (20, 29, 'Sub_Category')]}),
#  ('get Bottom Line  Breakfast in month Apr to Dec?',
#   {'entities': [(4, 15, 'Task'), (17, 26, 'Category')]}),
#  ('get Top Line  Publix in quarter Q1?',
#   {'entities': [(4, 12, 'Task'), (14, 20, 'Customer')]}),
#  ('fetch Gross Sales  All others in quarter Q1 to Q4?',
#   {'entities': [(6, 17, 'Task'), (19, 29, 'Sub_Category')]}),
#  ('display Gross Sales  Grated in month Jun?',
#   {'entities': [(8, 19, 'Task'), (21, 27, 'Sub_Category')]}),
#  ('get Revenue  Dollar General in month May to Sep?',
#   {'entities': [(4, 11, 'Task'), (13, 27, 'Customer')]}),
#  ('fetch Gross Sales  Coffee in week Wk2?',
#   {'entities': [(6, 17, 'Task'), (19, 25, 'Sub_Category')]}),
#  ('generate Gross Sales  Grated in week Wk19 to Wk32?',
#   {'entities': [(9, 20, 'Task'), (22, 28, 'Sub_Category')]}),
#  ('fetch Max Shipment  Meats in quarter Q2?',
#   {'entities': [(6, 18, 'Task'), (20, 25, 'Category')]}),
#  ('generate Top Line  Aldi in quarter Q2 to Q4?',
#   {'entities': [(9, 17, 'Task'), (19, 23, 'Customer')]}),
#  ('display Revenue  Aldi in month Jun?',
#   {'entities': [(8, 15, 'Task'), (17, 21, 'Customer')]}),
#  ('generate Max Shipment  Aldi in quarter Q2 to Q4?',
#   {'entities': [(9, 21, 'Task'), (23, 27, 'Customer')]}),
#  ('fetch Revenue  Breakfast in year 2019?',
#   {'entities': [(6, 13, 'Task'), (15, 24, 'Category')]}),
#  ('fetch Gross Sales  Amazon in year 2019?',
#   {'entities': [(6, 17, 'Task'), (19, 25, 'Customer')]}),
#  ('fetch Net sales  Costco in month Dec?',
#   {'entities': [(6, 15, 'Task'), (17, 23, 'Customer')]}),
#  ('fetch Top Line  Aldi in week Wk23 to Wk42?',
#   {'entities': [(6, 14, 'Task'), (16, 20, 'Customer')]}),
#  ('fetch Revenue  Hard in month Jan?',
#   {'entities': [(6, 13, 'Task'), (15, 19, 'Sub_Category')]}),
#  ('generate Count  Meats in quarter Q2 to Q4?',
#   {'entities': [(9, 14, 'Task'), (16, 21, 'Category')]}),
#  ('generate Net sales  Candy in quarter Q2?',
#   {'entities': [(9, 18, 'Task'), (20, 25, 'Category')]}),
#  ('display Top Line  Bacon in month Jun to Oct?',
#   {'entities': [(8, 16, 'Task'), (18, 23, 'Sub_Category')]}),
#  ('display Max Shipment  Enhancers in month Aug?',
#   {'entities': [(8, 20, 'Task'), (22, 31, 'Sub_Category')]}),
#  ('get Top Line  Sauces in quarter Q1 to Q4?',
#   {'entities': [(4, 12, 'Task'), (14, 20, 'Category')]}),
#  ('generate Net sales  Candy in year 2019?',
#   {'entities': [(9, 18, 'Task'), (20, 25, 'Category')]}),
#  ('display Net sales  Albertsons/Safeway in month Jun to Aug?',
#   {'entities': [(8, 17, 'Task'), (19, 37, 'Customer')]}),
#  ('get Max Shipment  Cheese in week Wk23?',
#   {'entities': [(4, 16, 'Task'), (18, 24, 'Category')]}),
#  ('fetch Net sales  Specialty Meats in week Wk22 to Wk49?',
#   {'entities': [(6, 15, 'Task'), (17, 32, 'Sub_Category')]}),
#  ('get Count  UNIFI in quarter Q3?',
#   {'entities': [(4, 9, 'Task'), (11, 16, 'Customer')]}),
#  ('fetch Bottom Line  Coffee in year 2019?',
#   {'entities': [(6, 17, 'Task'), (19, 25, 'Sub_Category')]}),
#  ('get Net sales  Natural Cheese in month Aug?',
#   {'entities': [(4, 13, 'Task'), (15, 29, 'Sub_Category')]}),
#  ('display Count  Dollar General in quarter Q2 to Q4?',
#   {'entities': [(8, 13, 'Task'), (15, 29, 'Customer')]}),
#  ('generate Max Shipment  Meats in year 2019?',
#   {'entities': [(9, 21, 'Task'), (23, 28, 'Category')]}),
#  ('generate Max Shipment  Bars/Snacks in month Apr to Sep?',
#   {'entities': [(9, 21, 'Task'), (23, 34, 'Sub_Category')]}),
#  ('fetch Top Line  Meats in month Oct?',
#   {'entities': [(6, 14, 'Task'), (16, 21, 'Category')]}),
#  ('fetch Bottom Line  Aldi in week Wk5 to Wk40?',
#   {'entities': [(6, 17, 'Task'), (19, 23, 'Customer')]}),
#  ('generate Count  Juice in month Oct?',
#   {'entities': [(9, 14, 'Task'), (16, 21, 'Sub_Category')]}),
#  ('generate Top Line  Mayonaise in week Wk16 to Wk46?',
#   {'entities': [(9, 17, 'Task'), (19, 28, 'Sub_Category')]}),
#  ('display Max Shipment  Meats in month Dec?',
#   {'entities': [(8, 20, 'Task'), (22, 27, 'Category')]}),
#  ('generate Bottom Line  Cheese in quarter Q2 to Q4?',
#   {'entities': [(9, 20, 'Task'), (22, 28, 'Category')]}),
#  ('generate Count  Processed Cheese in year 2019?',
#   {'entities': [(9, 14, 'Task'), (16, 32, 'Sub_Category')]}),
#  ('fetch Net sales  Candy in year 2019?',
#   {'entities': [(6, 15, 'Task'), (17, 22, 'Category')]}),
#  ('fetch Bottom Line  Breakfast in quarter Q1?',
#   {'entities': [(6, 17, 'Task'), (19, 28, 'Category')]}),
#  ('generate Revenue  Processed Cheese in month May to Oct?',
#   {'entities': [(9, 16, 'Task'), (18, 34, 'Sub_Category')]}),
#  ('display Count  BBQ in quarter Q2?',
#   {'entities': [(8, 13, 'Task'), (15, 18, 'Sub_Category')]}),
#  ('get Top Line  Juice in year 2019?',
#   {'entities': [(4, 12, 'Task'), (14, 19, 'Sub_Category')]}),
#  ('fetch Count  Natural Cheese in quarter Q2?',
#   {'entities': [(6, 11, 'Task'), (13, 27, 'Sub_Category')]}),
#  ('get Revenue  Amazon in quarter Q2 to Q4?',
#   {'entities': [(4, 11, 'Task'), (13, 19, 'Customer')]}),
#  ('display Top Line  Kroger in week Wk11?',
#   {'entities': [(8, 16, 'Task'), (18, 24, 'Customer')]}),
#  ('display Net sales  Target in month Jun to Sep?',
#   {'entities': [(8, 17, 'Task'), (19, 25, 'Customer')]}),
#  ('fetch Count  Natural Cheese in week Wk7?',
#   {'entities': [(6, 11, 'Task'), (13, 27, 'Sub_Category')]}),
#  ('fetch Net sales  Aldi in week Wk4 to Wk43?',
#   {'entities': [(6, 15, 'Task'), (17, 21, 'Customer')]}),
#  ('get Bottom Line  Bacon in quarter Q3?',
#   {'entities': [(4, 15, 'Task'), (17, 22, 'Sub_Category')]}),
#  ('generate Net sales  Mayonaise in year 2019?',
#   {'entities': [(9, 18, 'Task'), (20, 29, 'Sub_Category')]}),
#  ('fetch Gross Sales  Aldi in quarter Q4?',
#   {'entities': [(6, 17, 'Task'), (19, 23, 'Customer')]}),
#  ('get Net sales  Meats in year 2019?',
#   {'entities': [(4, 13, 'Task'), (15, 20, 'Category')]}),
#  ('get Net sales  Dollar General in month Apr?',
#   {'entities': [(4, 13, 'Task'), (15, 29, 'Customer')]}),
#  ('fetch Net sales  Cheese in year 2019?',
#   {'entities': [(6, 15, 'Task'), (17, 23, 'Category')]}),
#  ('generate Top Line  Aldi in year 2019?',
#   {'entities': [(9, 17, 'Task'), (19, 23, 'Customer')]}),
#  ('fetch Net sales  Ketchup in year 2019?',
#   {'entities': [(6, 15, 'Task'), (17, 24, 'Sub_Category')]}),
#  ('get Max Shipment  UNIFI in year 2019?',
#   {'entities': [(4, 16, 'Task'), (18, 23, 'Customer')]}),
#  ('get Top Line  Ahold in quarter Q1 to Q4?',
#   {'entities': [(4, 12, 'Task'), (14, 19, 'Customer')]}),
#  ('display Max Shipment  Candy in month Aug?',
#   {'entities': [(8, 20, 'Task'), (22, 27, 'Category')]}),
#  ('fetch Bottom Line  Meats in week Wk21 to Wk35?',
#   {'entities': [(6, 17, 'Task'), (19, 24, 'Category')]}),
#  ('generate Max Shipment  Juice in quarter Q3?',
#   {'entities': [(9, 21, 'Task'), (23, 28, 'Sub_Category')]}),
#  ('fetch Count  Chocolate in year 2019?',
#   {'entities': [(6, 11, 'Task'), (13, 22, 'Sub_Category')]}),
#  ('get Revenue  Costco in week Wk28?',
#   {'entities': [(4, 11, 'Task'), (13, 19, 'Customer')]}),
#  ('generate Gross Sales  Bars/Snacks in month Apr to Dec?',
#   {'entities': [(9, 20, 'Task'), (22, 33, 'Sub_Category')]}),
#  ('display Top Line  Coffee in quarter Q2?',
#   {'entities': [(8, 16, 'Task'), (18, 24, 'Sub_Category')]}),
#  ('display Count  Caramels in quarter Q2 to Q4?',
#   {'entities': [(8, 13, 'Task'), (15, 23, 'Sub_Category')]}),
#  ('fetch Bottom Line  Sauces in week Wk46?',
#   {'entities': [(6, 17, 'Task'), (19, 25, 'Category')]}),
#  ('fetch Top Line  Gelatin in week Wk20 to Wk32?',
#   {'entities': [(6, 14, 'Task'), (16, 23, 'Sub_Category')]}),
#  ('display Top Line  Albertsons/Safeway in quarter Q3?',
#   {'entities': [(8, 16, 'Task'), (18, 36, 'Customer')]}),
#  ('generate Max Shipment  Sauces in month Feb to Nov?',
#   {'entities': [(9, 21, 'Task'), (23, 29, 'Category')]}),
#  ('get Bottom Line  Breakfast in week Wk38?',
#   {'entities': [(4, 15, 'Task'), (17, 26, 'Category')]}),
#  ('generate Gross Sales  Tea in month Feb to Oct?',
#   {'entities': [(9, 20, 'Task'), (22, 25, 'Sub_Category')]}),
#  ('display Top Line  Chocolate in year 2019?',
#   {'entities': [(8, 16, 'Task'), (18, 27, 'Sub_Category')]}),
#  ('generate Gross Sales  UNIFI in quarter Q1 to Q4?',
#   {'entities': [(9, 20, 'Task'), (22, 27, 'Customer')]}),
#  ('display Net sales  Target in month Oct?',
#   {'entities': [(8, 17, 'Task'), (19, 25, 'Customer')]}),
#  ('generate Net sales  Cheese in week Wk12 to Wk44?',
#   {'entities': [(9, 18, 'Task'), (20, 26, 'Category')]}),
#  ('generate Net sales  Albertsons/Safeway in month Feb?',
#   {'entities': [(9, 18, 'Task'), (20, 38, 'Customer')]}),
#  ('generate Gross Sales  Amazon in month May to Oct?',
#   {'entities': [(9, 20, 'Task'), (22, 28, 'Customer')]}),
#  ('generate Count  Mayonaise in quarter Q4?',
#   {'entities': [(9, 14, 'Task'), (16, 25, 'Sub_Category')]}),
#  ('get Top Line  Juice in month May to Sep?',
#   {'entities': [(4, 12, 'Task'), (14, 19, 'Sub_Category')]}),
#  ('get Revenue  Albertsons/Safeway in year 2019?',
#   {'entities': [(4, 11, 'Task'), (13, 31, 'Customer')]}),
#  ('generate Max Shipment  Specialty Meats in quarter Q2 to Q4?',
#   {'entities': [(9, 21, 'Task'), (23, 38, 'Sub_Category')]}),
#  ('get Gross Sales  Natural Cheese in month Jan?',
#   {'entities': [(4, 15, 'Task'), (17, 31, 'Sub_Category')]}),
#  ('display Bottom Line  Cheese in quarter Q2 to Q4?',
#   {'entities': [(8, 19, 'Task'), (21, 27, 'Category')]}),
#  ('fetch Bottom Line  BBQ in week Wk52?',
#   {'entities': [(6, 17, 'Task'), (19, 22, 'Sub_Category')]}),
#  ('get Count  BBQ in year 2019?',
#   {'entities': [(4, 9, 'Task'), (11, 14, 'Sub_Category')]}),
#  ('get Top Line  Ketchup in year 2019?',
#   {'entities': [(4, 12, 'Task'), (14, 21, 'Sub_Category')]}),
#  ('fetch Bottom Line  Candy in week Wk10 to Wk49?',
#   {'entities': [(6, 17, 'Task'), (19, 24, 'Category')]}),
#  ('generate Bottom Line  Tea in month Feb?',
#   {'entities': [(9, 20, 'Task'), (22, 25, 'Sub_Category')]}),
#  ('get Max Shipment  Breakfast in week Wk20 to Wk29?',
#   {'entities': [(4, 16, 'Task'), (18, 27, 'Category')]}),
#  ('generate Count  Bacon in week Wk34?',
#   {'entities': [(9, 14, 'Task'), (16, 21, 'Sub_Category')]}),
#  ('generate Count  Sauces in year 2019?',
#   {'entities': [(9, 14, 'Task'), (16, 22, 'Category')]}),
#  ('display Net sales  Candy in year 2019?',
#   {'entities': [(8, 17, 'Task'), (19, 24, 'Category')]}),
#  ('get Bottom Line  Processed Cheese in year 2019?',
#   {'entities': [(4, 15, 'Task'), (17, 33, 'Sub_Category')]}),
#  ('display Net sales  Hard in quarter Q4?',
#   {'entities': [(8, 17, 'Task'), (19, 23, 'Sub_Category')]}),
#  ('generate Bottom Line  Kroger in month Mar to Sep?',
#   {'entities': [(9, 20, 'Task'), (22, 28, 'Customer')]}),
#  ('get Gross Sales  Meats in month Mar?',
#   {'entities': [(4, 15, 'Task'), (17, 22, 'Category')]}),
#  ('display Max Shipment  Amazon in month Mar to Nov?',
#   {'entities': [(8, 20, 'Task'), (22, 28, 'Customer')]}),
#  ('display Net sales  Cheese in quarter Q2?',
#   {'entities': [(8, 17, 'Task'), (19, 25, 'Category')]}),
#  ('generate Max Shipment  Breakfast in quarter Q1 to Q4?',
#   {'entities': [(9, 21, 'Task'), (23, 32, 'Category')]}),
#  ('fetch Max Shipment  Cheese in quarter Q3?',
#   {'entities': [(6, 18, 'Task'), (20, 26, 'Category')]}),
#  ('get Bottom Line  Cheese in quarter Q1 to Q4?',
#   {'entities': [(4, 15, 'Task'), (17, 23, 'Category')]}),
#  ('fetch Top Line  Coffee in week Wk46?',
#   {'entities': [(6, 14, 'Task'), (16, 22, 'Sub_Category')]}),
#  ('get Top Line  Sauces in year 2019?',
#   {'entities': [(4, 12, 'Task'), (14, 20, 'Category')]}),
#  ('fetch Revenue  Candy in week Wk49?',
#   {'entities': [(6, 13, 'Task'), (15, 20, 'Category')]}),
#  ('get Gross Sales  Cheese in month Apr to Dec?',
#   {'entities': [(4, 15, 'Task'), (17, 23, 'Category')]}),
#  ('display Count  Juice in week Wk37?',
#   {'entities': [(8, 13, 'Task'), (15, 20, 'Sub_Category')]}),
#  ('fetch Gross Sales  Tea in month Apr to Dec?',
#   {'entities': [(6, 17, 'Task'), (19, 22, 'Sub_Category')]}),
#  ('get Count  Coffee in quarter Q2?',
#   {'entities': [(4, 9, 'Task'), (11, 17, 'Sub_Category')]}),
#  ('get Net sales  Cheese in year 2019?',
#   {'entities': [(4, 13, 'Task'), (15, 21, 'Category')]}),
#  ('display Max Shipment  Caramels in week Wk46?',
#   {'entities': [(8, 20, 'Task'), (22, 30, 'Sub_Category')]}),
#  ('get Bottom Line  Walmart in week Wk16 to Wk31?',
#   {'entities': [(4, 15, 'Task'), (17, 24, 'Customer')]}),
#  ('fetch Top Line  Sauces in year 2019?',
#   {'entities': [(6, 14, 'Task'), (16, 22, 'Category')]}),
#  ('display Bottom Line  Aldi in month Feb to Nov?',
#   {'entities': [(8, 19, 'Task'), (21, 25, 'Customer')]}),
#  ('get Bottom Line  Coffee in week Wk16?',
#   {'entities': [(4, 15, 'Task'), (17, 23, 'Sub_Category')]}),
#  ('get Gross Sales  Meats in week Wk5 to Wk35?',
#   {'entities': [(4, 15, 'Task'), (17, 22, 'Category')]}),
#  ('get Bottom Line  Caramels in month Jul?',
#   {'entities': [(4, 15, 'Task'), (17, 25, 'Sub_Category')]}),
#  ('display Gross Sales  Amazon in year 2019?',
#   {'entities': [(8, 19, 'Task'), (21, 27, 'Customer')]}),
#  ('display Top Line  Candy in year 2019?',
#   {'entities': [(8, 16, 'Task'), (18, 23, 'Category')]}),
#  ('generate Gross Sales  Candy in quarter Q2 to Q4?',
#   {'entities': [(9, 20, 'Task'), (22, 27, 'Category')]}),
#  ('display Count  Meats in year 2019?',
#   {'entities': [(8, 13, 'Task'), (15, 20, 'Category')]}),
# ...
#  ('generate Max Shipment  Candy in month Mar to Nov?',
#   {'entities': [(9, 21, 'Task'), (23, 28, 'Category')]}),
#  ('display Count  Mayonaise in month Feb?',
#   {'entities': [(8, 13, 'Task'), (15, 24, 'Sub_Category')]}),
#  ('display Gross Sales  Breakfast in quarter Q1 to Q4?',
#   {'entities': [(8, 19, 'Task'), (21, 30, 'Category')]}),
#  ('display Revenue  Cheese in year 2019?',
#   {'entities': [(8, 15, 'Task'), (17, 23, 'Category')]}),
#  ('generate Net sales  Gelatin in year 2019?',
#   {'entities': [(9, 18, 'Task'), (20, 27, 'Sub_Category')]}),
#  ('get Top Line  Sauces in month Dec?',
#   {'entities': [(4, 12, 'Task'), (14, 20, 'Category')]}),
#  ('display Revenue  Meats in month Jan to Aug?',
#   {'entities': [(8, 15, 'Task'), (17, 22, 'Category')]}),
#  ('display Top Line  Shelf Stable in year 2019?',
#   {'entities': [(8, 16, 'Task'), (18, 30, 'Sub_Category')]}),
#  ('display Gross Sales  Sauces in year 2019?',
#   {'entities': [(8, 19, 'Task'), (21, 27, 'Category')]}),
#  ('get Count  Hot Dogs in year 2019?',
#   {'entities': [(4, 9, 'Task'), (11, 19, 'Sub_Category')]}),
#  ('generate Count  Ketchup in quarter Q2 to Q4?',
#   {'entities': [(9, 14, 'Task'), (16, 23, 'Sub_Category')]}),
#  ('display Top Line  Dollar General in month Nov?',
#   {'entities': [(8, 16, 'Task'), (18, 32, 'Customer')]}),
#  ('get Net sales  Hard in year 2019?',
#   {'entities': [(4, 13, 'Task'), (15, 19, 'Sub_Category')]}),
#  ('fetch Bottom Line  Hot Dogs in week Wk16?',
#   {'entities': [(6, 17, 'Task'), (19, 27, 'Sub_Category')]}),
#  ('display Net sales  Cheese in month Mar to Oct?',
#   {'entities': [(8, 17, 'Task'), (19, 25, 'Category')]}),
#  ('get Max Shipment  Creamers in month Jun?',
#   {'entities': [(4, 16, 'Task'), (18, 26, 'Sub_Category')]}),
#  ('get Gross Sales  Sauces in month Jan to Oct?',
#   {'entities': [(4, 15, 'Task'), (17, 23, 'Category')]}),
#  ('get Top Line  Meats in month Feb?',
#   {'entities': [(4, 12, 'Task'), (14, 19, 'Category')]}),
#  ('get Top Line  Cheese in week Wk2 to Wk39?',
#   {'entities': [(4, 12, 'Task'), (14, 20, 'Category')]}),
#  ('generate Top Line  Breakfast in quarter Q1?',
#   {'entities': [(9, 17, 'Task'), (19, 28, 'Category')]}),
#  ('get Count  Walmart in year 2019?',
#   {'entities': [(4, 9, 'Task'), (11, 18, 'Customer')]}),
#  ('display Net sales  Meats in month Jan?',
#   {'entities': [(8, 17, 'Task'), (19, 24, 'Category')]}),
#  ('display Net sales  Target in month Jan to Dec?',
#   {'entities': [(8, 17, 'Task'), (19, 25, 'Customer')]}),
#  ('get Top Line  Processed Cheese in quarter Q3?',
#   {'entities': [(4, 12, 'Task'), (14, 30, 'Sub_Category')]}),
#  ('generate Count  Meats in week Wk12 to Wk37?',
#   {'entities': [(9, 14, 'Task'), (16, 21, 'Category')]}),
#  ('get Bottom Line  Creamers in month Nov?',
#   {'entities': [(4, 15, 'Task'), (17, 25, 'Sub_Category')]}),
#  ('display Count  Shelf Stable in year 2019?',
#   {'entities': [(8, 13, 'Task'), (15, 27, 'Sub_Category')]}),
#  ('get Count  Publix in week Wk31?',
#   {'entities': [(4, 9, 'Task'), (11, 17, 'Customer')]}),
#  ('get Top Line  Sauces in quarter Q2 to Q4?',
#   {'entities': [(4, 12, 'Task'), (14, 20, 'Category')]}),
#  ('generate Net sales  Candy in week Wk43?',
#   {'entities': [(9, 18, 'Task'), (20, 25, 'Category')]}),
#  ('generate Top Line  Cheese in year 2019?',
#   {'entities': [(9, 17, 'Task'), (19, 25, 'Category')]}),
#  ('fetch Top Line  Tea in month Feb?',
#   {'entities': [(6, 14, 'Task'), (16, 19, 'Sub_Category')]}),
#  ('generate Top Line  Breakfast in quarter Q2 to Q4?',
#   {'entities': [(9, 17, 'Task'), (19, 28, 'Category')]}),
#  ('get Max Shipment  Candy in year 2019?',
#   {'entities': [(4, 16, 'Task'), (18, 23, 'Category')]}),
#  ('fetch Count  Processed Cheese in quarter Q2 to Q4?',
#   {'entities': [(6, 11, 'Task'), (13, 29, 'Sub_Category')]}),
#  ('generate Revenue  Sauces in quarter Q3?',
#   {'entities': [(9, 16, 'Task'), (18, 24, 'Category')]}),
#  ('get Net sales  Breakfast in week Wk24 to Wk27?',
#   {'entities': [(4, 13, 'Task'), (15, 24, 'Category')]}),
#  ('display Count  Natural Cheese in quarter Q2?',
#   {'entities': [(8, 13, 'Task'), (15, 29, 'Sub_Category')]}),
#  ('fetch Gross Sales  Enhancers in year 2019?',
#   {'entities': [(6, 17, 'Task'), (19, 28, 'Sub_Category')]}),
#  ('fetch Count  Bacon in year 2019?',
#   {'entities': [(6, 11, 'Task'), (13, 18, 'Sub_Category')]}),
#  ('fetch Net sales  Bars/Snacks in week Wk2 to Wk29?',
#   {'entities': [(6, 15, 'Task'), (17, 28, 'Sub_Category')]}),
#  ('fetch Bottom Line  Shelf Stable in year 2019?',
#   {'entities': [(6, 17, 'Task'), (19, 31, 'Sub_Category')]}),
#  ('fetch Count  Candy in year 2019?',
#   {'entities': [(6, 11, 'Task'), (13, 18, 'Category')]}),
#  ('generate Net sales  Sauces in month Oct?',
#   {'entities': [(9, 18, 'Task'), (20, 26, 'Category')]}),
#  ('fetch Top Line  Bars/Snacks in quarter Q2 to Q4?',
#   {'entities': [(6, 14, 'Task'), (16, 27, 'Sub_Category')]}),
#  ('display Top Line  Publix in quarter Q1?',
#   {'entities': [(8, 16, 'Task'), (18, 24, 'Customer')]}),
#  ('generate Revenue  Ahold in year 2019?',
#   {'entities': [(9, 16, 'Task'), (18, 23, 'Customer')]}),
#  ('get Bottom Line  Meats in quarter Q4?',
#   {'entities': [(4, 15, 'Task'), (17, 22, 'Category')]}),
#  ('get Top Line  Tea in month May to Nov?',
#   {'entities': [(4, 12, 'Task'), (14, 17, 'Sub_Category')]}),
#  ('get Max Shipment  Cold Cuts in quarter Q2?',
#   {'entities': [(4, 16, 'Task'), (18, 27, 'Sub_Category')]}),
#  ('display Max Shipment  Cheese in quarter Q2 to Q4?',
#   {'entities': [(8, 20, 'Task'), (22, 28, 'Category')]}),
#  ('get Revenue  Natural Cheese in month Apr?',
#   {'entities': [(4, 11, 'Task'), (13, 27, 'Sub_Category')]}),
#  ('fetch Max Shipment  Juice in quarter Q2 to Q4?',
#   {'entities': [(6, 18, 'Task'), (20, 25, 'Sub_Category')]}),
#  ('get Top Line  Target in quarter Q4?',
#   {'entities': [(4, 12, 'Task'), (14, 20, 'Customer')]}),
#  ('fetch Bottom Line  Costco in month Mar to Dec?',
#   {'entities': [(6, 17, 'Task'), (19, 25, 'Customer')]}),
#  ('display Top Line  Meats in quarter Q4?',
#   {'entities': [(8, 16, 'Task'), (18, 23, 'Category')]}),
#  ('generate Bottom Line  Albertsons/Safeway in week Wk21 to Wk41?',
#   {'entities': [(9, 20, 'Task'), (22, 40, 'Customer')]}),
#  ('fetch Bottom Line  Candy in quarter Q2?',
#   {'entities': [(6, 17, 'Task'), (19, 24, 'Category')]}),
#  ('generate Count  Publix in month Jan to Aug?',
#   {'entities': [(9, 14, 'Task'), (16, 22, 'Customer')]}),
#  ('get Bottom Line  Cheese in quarter Q2?',
#   {'entities': [(4, 15, 'Task'), (17, 23, 'Category')]}),
#  ('get Top Line  Kroger in week Wk24 to Wk30?',
#   {'entities': [(4, 12, 'Task'), (14, 20, 'Customer')]}),
#  ('fetch Top Line  Candy in year 2019?',
#   {'entities': [(6, 14, 'Task'), (16, 21, 'Category')]}),
#  ('display Max Shipment  All others in month Mar to Nov?',
#   {'entities': [(8, 20, 'Task'), (22, 32, 'Sub_Category')]}),
#  ('generate Net sales  Bars/Snacks in month Feb?',
#   {'entities': [(9, 18, 'Task'), (20, 31, 'Sub_Category')]}),
#  ('fetch Net sales  Cheese in year 2019?',
#   {'entities': [(6, 15, 'Task'), (17, 23, 'Category')]}),
#  ('generate Revenue  Bacon in quarter Q3?',
#   {'entities': [(9, 16, 'Task'), (18, 23, 'Sub_Category')]}),
#  ('fetch Count  BBQ in week Wk10 to Wk49?',
#   {'entities': [(6, 11, 'Task'), (13, 16, 'Sub_Category')]}),
#  ('get Gross Sales  Grated in month Aug?',
#   {'entities': [(4, 15, 'Task'), (17, 23, 'Sub_Category')]}),
#  ('generate Net sales  UNIFI in week Wk23 to Wk34?',
#   {'entities': [(9, 18, 'Task'), (20, 25, 'Customer')]}),
#  ('generate Revenue  Breakfast in month Jul?',
#   {'entities': [(9, 16, 'Task'), (18, 27, 'Category')]}),
#  ('get Max Shipment  Bacon in month Feb to Sep?',
#   {'entities': [(4, 16, 'Task'), (18, 23, 'Sub_Category')]}),
#  ('display Gross Sales  Cold Cuts in year 2019?',
#   {'entities': [(8, 19, 'Task'), (21, 30, 'Sub_Category')]}),
#  ('fetch Gross Sales  Caramels in week Wk6 to Wk34?',
#   {'entities': [(6, 17, 'Task'), (19, 27, 'Sub_Category')]}),
#  ('get Top Line  Sauces in quarter Q2?',
#   {'entities': [(4, 12, 'Task'), (14, 20, 'Category')]}),
#  ('get Count  Chocolate in quarter Q2 to Q4?',
#   {'entities': [(4, 9, 'Task'), (11, 20, 'Sub_Category')]}),
#  ('get Net sales  Processed Cheese in month Sep?',
#   {'entities': [(4, 13, 'Task'), (15, 31, 'Sub_Category')]}),
#  ('get Net sales  Dollar General in month Jan to Sep?',
#   {'entities': [(4, 13, 'Task'), (15, 29, 'Customer')]}),
#  ('generate Max Shipment  Mayonaise in year 2019?',
#   {'entities': [(9, 21, 'Task'), (23, 32, 'Sub_Category')]}),
#  ('generate Bottom Line  Meats in quarter Q1 to Q4?',
#   {'entities': [(9, 20, 'Task'), (22, 27, 'Category')]}),
#  ('generate Bottom Line  Amazon in month Feb?',
#   {'entities': [(9, 20, 'Task'), (22, 28, 'Customer')]}),
#  ('fetch Gross Sales  Creamers in quarter Q1 to Q4?',
#   {'entities': [(6, 17, 'Task'), (19, 27, 'Sub_Category')]}),
#  ('display Revenue  Publix in week Wk47?',
#   {'entities': [(8, 15, 'Task'), (17, 23, 'Customer')]}),
#  ('get Revenue  Cheese in year 2019?',
#   {'entities': [(4, 11, 'Task'), (13, 19, 'Category')]}),
#  ('display Gross Sales  Albertsons/Safeway in year 2019?',
#   {'entities': [(8, 19, 'Task'), (21, 39, 'Customer')]}),
#  ('generate Count  Dollar General in quarter Q2 to Q4?',
#   {'entities': [(9, 14, 'Task'), (16, 30, 'Customer')]}),
#  ('fetch Net sales  Amazon in week Wk4?',
#   {'entities': [(6, 15, 'Task'), (17, 23, 'Customer')]}),
#  ('fetch Count  Sauces in year 2019?',
#   {'entities': [(6, 11, 'Task'), (13, 19, 'Category')]}),
#  ('get Net sales  Costco in month Oct?',
#   {'entities': [(4, 13, 'Task'), (15, 21, 'Customer')]}),
#  ('display Count  Meats in month Apr to Dec?',
#   {'entities': [(8, 13, 'Task'), (15, 20, 'Category')]}),
#  ('get Net sales  Enhancers in week Wk2?',
#   {'entities': [(4, 13, 'Task'), (15, 24, 'Sub_Category')]}),
#  ('display Net sales  Sauces in month Mar to Dec?',
#   {'entities': [(8, 17, 'Task'), (19, 25, 'Category')]}),
#  ('get Revenue  Aldi in week Wk2?',
#   {'entities': [(4, 11, 'Task'), (13, 17, 'Customer')]}),
#  ('fetch Gross Sales  Ahold in quarter Q1 to Q4?',
#   {'entities': [(6, 17, 'Task'), (19, 24, 'Customer')]}),
#  ('generate Count  Cheese in quarter Q1?',
#   {'entities': [(9, 14, 'Task'), (16, 22, 'Category')]}),
#  ('get Bottom Line  Breakfast in quarter Q1 to Q4?',
#   {'entities': [(4, 15, 'Task'), (17, 26, 'Category')]}),
#  ('fetch Top Line  Albertsons/Safeway in quarter Q1?',
#   {'entities': [(6, 14, 'Task'), (16, 34, 'Customer')]}),
#  ('fetch Revenue  Enhancers in year 2019?',
#   {'entities': [(6, 13, 'Task'), (15, 24, 'Sub_Category')]}),
#  ('fetch Revenue  Publix in year 2019?',
#   {'entities': [(6, 13, 'Task'), (15, 21, 'Customer')]}),
#  ('generate Revenue  BBQ in quarter Q1 to Q4?',
#   {'entities': [(9, 16, 'Task'), (18, 21, 'Sub_Category')]}),
#  ('display Revenue  Albertsons/Safeway in week Wk27?',
#   {'entities': [(8, 15, 'Task'), (17, 35, 'Customer')]}),
#  ('get Gross Sales  Candy in week Wk1 to Wk40?',
#   {'entities': [(4, 15, 'Task'), (17, 22, 'Category')]}),
#  ('get Top Line  Cheese in year 2019?',
#   {'entities': [(4, 12, 'Task'), (14, 20, 'Category')]}),
#  ('get Count  Cheese in month May to Aug?',
#   {'entities': [(4, 9, 'Task'), (11, 17, 'Category')]}),
#  ('fetch Top Line  Ahold in year 2019?',
#   {'entities': [(6, 14, 'Task'), (16, 21, 'Customer')]}),
#  ('fetch Gross Sales  Cheese in quarter Q1 to Q4?',
#   {'entities': [(6, 17, 'Task'), (19, 25, 'Category')]}),
#  ('display Top Line  Tea in week Wk36?',
#   {'entities': [(8, 16, 'Task'), (18, 21, 'Sub_Category')]}),
#  ('display Net sales  Dollar General in month Apr to Dec?',
#   {'entities': [(8, 17, 'Task'), (19, 33, 'Customer')]}),
#  ('generate Bottom Line  Sauces in year 2019?',
#   {'entities': [(9, 20, 'Task'), (22, 28, 'Category')]}),
#  ('fetch Gross Sales  Breakfast in week Wk24 to Wk27?',
#   {'entities': [(6, 17, 'Task'), (19, 28, 'Category')]}),
#  ('display Revenue  Candy in month Nov?',
#   {'entities': [(8, 15, 'Task'), (17, 22, 'Category')]}),
#  ('fetch Top Line  Dollar General in year 2019?',
#   {'entities': [(6, 14, 'Task'), (16, 30, 'Customer')]}),
#  ('fetch Bottom Line  Coffee in week Wk4?',
#   {'entities': [(6, 17, 'Task'), (19, 25, 'Sub_Category')]}),
#  ('get Top Line  Target in quarter Q1 to Q4?',
#   {'entities': [(4, 12, 'Task'), (14, 20, 'Customer')]}),
#  ('fetch Revenue  Juice in quarter Q3?',
#   {'entities': [(6, 13, 'Task'), (15, 20, 'Sub_Category')]}),
#  ('generate Bottom Line  Amazon in month Jan to Nov?',
#   {'entities': [(9, 20, 'Task'), (22, 28, 'Customer')]}),
#  ('display Gross Sales  Bars/Snacks in week Wk38?',
#   {'entities': [(8, 19, 'Task'), (21, 32, 'Sub_Category')]}),
#  ('get Top Line  Dollar General in week Wk21 to Wk39?',
#   {'entities': [(4, 12, 'Task'), (14, 28, 'Customer')]}),
#  ('display Max Shipment  Ahold in year 2019?',
#   {'entities': [(8, 20, 'Task'), (22, 27, 'Customer')]}),
#  ('display Revenue  Breakfast in week Wk13 to Wk34?',
#   {'entities': [(8, 15, 'Task'), (17, 26, 'Category')]}),
#  ('fetch Revenue  Sauces in week Wk14?',
#   {'entities': [(6, 13, 'Task'), (15, 21, 'Category')]}),
#  ('generate Revenue  Natural Cheese in month Jan to Sep?',
#   {'entities': [(9, 16, 'Task'), (18, 32, 'Sub_Category')]}),
#  ('get Count  Shelf Stable in month Feb?',
#   {'entities': [(4, 9, 'Task'), (11, 23, 'Sub_Category')]}),
#  ('generate Top Line  Costco in month Apr to Oct?',
#   {'entities': [(9, 17, 'Task'), (19, 25, 'Customer')]}),
#  ('get Revenue  Cheese in year 2019?',
#   {'entities': [(4, 11, 'Task'), (13, 19, 'Category')]}),
#  ('generate Gross Sales  Publix in quarter Q2 to Q4?',
#   {'entities': [(9, 20, 'Task'), (22, 28, 'Customer')]}),
#  ('display Count  Bars/Snacks in year 2019?',
#   {'entities': [(8, 13, 'Task'), (15, 26, 'Sub_Category')]}),
#  ('generate Top Line  Cheese in month Apr to Aug?',
#   {'entities': [(9, 17, 'Task'), (19, 25, 'Category')]}),
#  ('fetch Max Shipment  Cheese in quarter Q3?',
#   {'entities': [(6, 18, 'Task'), (20, 26, 'Category')]}),
#  ('fetch Bottom Line  Target in year 2019?',
#   {'entities': [(6, 17, 'Task'), (19, 25, 'Customer')]}),
#  ('display Bottom Line  Processed Cheese in month Jan?',
#   {'entities': [(8, 19, 'Task'), (21, 37, 'Sub_Category')]}),
#  ('display Revenue  Breakfast in quarter Q2 to Q4?',
#   {'entities': [(8, 15, 'Task'), (17, 26, 'Category')]}),
#  ('generate Count  Aldi in quarter Q4?',
#   {'entities': [(9, 14, 'Task'), (16, 20, 'Customer')]}),
#  ('fetch Top Line  Ahold in quarter Q1 to Q4?',
#   {'entities': [(6, 14, 'Task'), (16, 21, 'Customer')]}),
#  ('display Gross Sales  UNIFI in year 2019?',
#   {'entities': [(8, 19, 'Task'), (21, 26, 'Customer')]}),
#  ('display Top Line  Kroger in quarter Q1 to Q4?',
#   {'entities': [(8, 16, 'Task'), (18, 24, 'Customer')]}),
#  ('fetch Max Shipment  Ahold in quarter Q2?',
#   {'entities': [(6, 18, 'Task'), (20, 25, 'Customer')]}),
#  ('generate Revenue  Costco in week Wk16 to Wk29?',
#   {'entities': [(9, 16, 'Task'), (18, 24, 'Customer')]}),
#  ('display Revenue  Bars/Snacks in month Apr?',
#   {'entities': [(8, 15, 'Task'), (17, 28, 'Sub_Category')]}),
#  ('generate Count  Dollar General in week Wk11 to Wk33?',
#   {'entities': [(9, 14, 'Task'), (16, 30, 'Customer')]}),
#  ('generate Count  Cheese in month Jul?',
#   {'entities': [(9, 14, 'Task'), (16, 22, 'Category')]}),
#  ('display Max Shipment  Bacon in month Jan to Sep?',
#   {'entities': [(8, 20, 'Task'), (22, 27, 'Sub_Category')]}),
#  ('generate Count  Breakfast in year 2019?',
#   {'entities': [(9, 14, 'Task'), (16, 25, 'Category')]}),
#  ('display Top Line  Ahold in quarter Q1 to Q4?',
#   {'entities': [(8, 16, 'Task'), (18, 23, 'Customer')]}),
#  ('generate Bottom Line  Aldi in week Wk43?',
#   {'entities': [(9, 20, 'Task'), (22, 26, 'Customer')]}),
#  ('fetch Net sales  Aldi in quarter Q2 to Q4?',
#   {'entities': [(6, 15, 'Task'), (17, 21, 'Customer')]}),
#  ('generate Count  Caramels in week Wk3?',
#   {'entities': [(9, 14, 'Task'), (16, 24, 'Sub_Category')]}),
#  ('generate Top Line  Hot Dogs in week Wk13 to Wk36?',
#   {'entities': [(9, 17, 'Task'), (19, 27, 'Sub_Category')]}),
#  ('get Count  Kroger in month Sep?',
#   {'entities': [(4, 9, 'Task'), (11, 17, 'Customer')]}),
#  ('fetch Max Shipment  Natural Cheese in year 2019?',
#   {'entities': [(6, 18, 'Task'), (20, 34, 'Sub_Category')]})]

# %% [markdown]
# ### Training

# %%
TRAIN_DATA = data

nlp = spacy.blank('en')  # create blank Language class
# create the built-in pipeline components and add them to the pipeline
# nlp.create_pipe works for built-ins that are registered with spaCy
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner, last=True)
       

# add labels
for _, annotations in TRAIN_DATA:
     for ent in annotations.get('entities'):
        ner.add_label(ent[2])

# %%
# get names of other pipes to disable them during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
iterations = 20
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    
    for itn in range(iterations):
        print("Statring iteration " + str(itn))
        random.shuffle(TRAIN_DATA)
        losses = {}
        for text, annotations in TRAIN_DATA:
            nlp.update(
                [text],  # batch of texts
                [annotations],  # batch of annotations
                drop=0.2,  # dropout - make it harder to memorise data
                sgd=optimizer,  # callable to update weights
                losses=losses)
        print(losses)
# Out:
# C:\Users\rahul.jha\anaconda3\lib\site-packages\spacy\language.py:635: UserWarning: [W033] Training a new parser or NER using a model with an empty lexeme normalization table. This may degrade the performance to some degree. If this is intentional or this language doesn't have a normalization table, please ignore this warning.
#   proc.begin_training(
# C:\Users\rahul.jha\anaconda3\lib\site-packages\spacy\language.py:635: UserWarning: [W034] Please install the package spacy-lookups-data in order to include the default lexeme normalization table for the language 'en'.
#   proc.begin_training(
# Statring iteration 0
# {'ner': 539.078071604505}
# Statring iteration 1
# {'ner': 8.093159410990522}
# Statring iteration 2
# {'ner': 0.012387057179723588}
# Statring iteration 3
# {'ner': 108.61125278398958}
# Statring iteration 4
# {'ner': 0.00028191408839848}
# Statring iteration 5
# {'ner': 0.0011553522642202118}
# Statring iteration 6
# {'ner': 67.61972112161425}
# Statring iteration 7
# {'ner': 5.9971986536485735}
# Statring iteration 8
# {'ner': 1.31534110109281e-06}
# Statring iteration 9
# {'ner': 63.742733820497776}
# Statring iteration 10
# {'ner': 4.947617364755552}
# Statring iteration 11
# {'ner': 2.7266675604888026e-05}
# Statring iteration 12
# {'ner': 8.341549517048614e-05}
# Statring iteration 13
# {'ner': 114.64027035482913}
# Statring iteration 14
# {'ner': 13.214697720386981}
# Statring iteration 15
# {'ner': 29.04505441085204}
# Statring iteration 16
# {'ner': 0.0025630773324564282}
# Statring iteration 17
# {'ner': 7.463689180085671e-09}
# Statring iteration 18
# {'ner': 2.9508983356218444e-05}
# Statring iteration 19
# {'ner': 37.95477442299551}

# %%
# Save our trained Model
nlp.to_disk('spacy_trained_model_v2')

# %% [markdown]
# ### Test Set Inference

# %%
df = pd.read_csv('Generated_English_Queries_v3_without_keyword_Test_Set.csv',keep_default_na=False)
df.head(2)
# Out:
#                                   English_Queries          Task Category  \
# 0     generate Max Shipment  Candy in quarter Q2?  Max Shipment    Candy
# 1  generate Top Line  Sauces in quarter Q1 to Q4?      Top Line   Sauces
#
#   Sub_Category Customer
# 0           NA       NA
# 1           NA       NA

# %%
entities = []
c = 1
for index,row in df.iterrows():
    values = ''
    doc = nlp(row['English_Queries'])
     
    for ent in doc.ents:
        values += ent.text + ':' + ent.label_ +' || '
    entities.append(values)

# %%
df['Entities'] = entities

# %%
df.head(50)
# Out:
#                                              English_Queries          Task  \
# 0                generate Max Shipment  Candy in quarter Q2?  Max Shipment
# 1             generate Top Line  Sauces in quarter Q1 to Q4?      Top Line
# 2                       display Net sales  Tea in month Nov?     Net sales
# 3                        get Top Line  Ketchup in year 2019?      Top Line
# 4                        get Revenue  Hot Dogs in month Aug?       Revenue
# 5              fetch Bottom Line  Candy in month Jun to Nov?   Bottom Line
# 6            fetch Revenue  Albertsons/Safeway in month Oct?       Revenue
# 7                        fetch Top Line  UNIFI in year 2019?      Top Line
# 8                         fetch Revenue  Meats in year 2019?       Revenue
# 9                fetch Revenue  Cheese in week Wk16 to Wk43?       Revenue
# 10                 generate Gross Sales  Meats in year 2019?   Gross Sales
# 11        display Bottom Line  Walmart in week Wk14 to Wk28?   Bottom Line
# 12                     get Max Shipment  Ahold in year 2019?  Max Shipment
# 13                  generate Net sales  Cheese in year 2019?     Net sales
# 14                        display Revenue  Tea in week Wk43?       Revenue
# 15                   get Count  Walmart in month Feb to Sep?         Count
# 16                     display Top Line  Candy in year 2019?      Top Line
# 17                  generate Bottom Line  Hard in year 2019?   Bottom Line
# 18                  fetch Max Shipment  Cheese in year 2019?  Max Shipment
# 19      fetch Net sales  Dollar General in month May to Dec?     Net sales
# 20           generate Top Line  Natural Cheese in month Jul?      Top Line
# 21                     fetch Net sales  Cheese in year 2019?     Net sales
# 22        fetch Max Shipment  Processed Cheese in year 2019?  Max Shipment
# 23     generate Max Shipment  Breakfast in week Wk6 to Wk42?  Max Shipment
# 24                       generate Count  Meats in year 2019?         Count
# 25               display Revenue  Candy in quarter Q2 to Q4?       Revenue
# 26                     generate Revenue  Target in week Wk4?       Revenue
# 27           display Max Shipment  Aldi in quarter Q2 to Q4?  Max Shipment
# 28                      generate Revenue  Aldi in year 2019?       Revenue
# 29                get Net sales  Cheese in month Feb to Oct?     Net sales
# 30               generate Max Shipment  Meats in quarter Q4?  Max Shipment
# 31  get Bottom Line  Albertsons/Safeway in quarter Q1 to Q4?   Bottom Line
# 32           display Gross Sales  Shelf Stable in year 2019?   Gross Sales
# 33                 get Net sales  Candy in quarter Q2 to Q4?     Net sales
# 34                  generate Count  Breakfast in quarter Q4?         Count
# 35               fetch Top Line  Publix in month Jan to Dec?      Top Line
# 36                  generate Top Line  Ketchup in week Wk18?      Top Line
# 37              get Gross Sales  Cheese in quarter Q1 to Q4?   Gross Sales
# 38                      get Revenue  Cold Cuts in year 2019?       Revenue
# 39                 get Revenue  Gelatin in month Apr to Nov?       Revenue
# 40                      display Count  Walmart in year 2019?         Count
# 41               get Bottom Line  Ahold in week Wk7 to Wk40?   Bottom Line
# 42                  generate Top Line  Ketchup in month Mar?      Top Line
# 43             display Revenue  Publix in week Wk22 to Wk31?       Revenue
# 44                       fetch Revenue  Target in year 2019?       Revenue
# 45           generate Gross Sales  Aldi in quarter Q2 to Q4?   Gross Sales
# 46                    get Gross Sales  Sauces in quarter Q4?   Gross Sales
# 47                    generate Revenue  Cheese in year 2019?       Revenue
# 48                    fetch Gross Sales  Candy in month Sep?   Gross Sales
# 49                  display Net sales  Walmart in year 2019?     Net sales
#
#      Category      Sub_Category            Customer  \
# 0       Candy                NA                  NA
# 1      Sauces                NA                  NA
# 2          NA               Tea                  NA
# 3          NA           Ketchup                  NA
# 4          NA          Hot Dogs                  NA
# 5       Candy                NA                  NA
# 6          NA                NA  Albertsons/Safeway
# 7          NA                NA               UNIFI
# 8       Meats                NA                  NA
# 9      Cheese                NA                  NA
# 10      Meats                NA                  NA
# 11         NA                NA             Walmart
# 12         NA                NA               Ahold
# 13     Cheese                NA                  NA
# 14         NA               Tea                  NA
# 15         NA                NA             Walmart
# 16      Candy                NA                  NA
# 17         NA              Hard                  NA
# 18     Cheese                NA                  NA
# 19         NA                NA      Dollar General
# 20         NA    Natural Cheese                  NA
# 21     Cheese                NA                  NA
# 22         NA  Processed Cheese                  NA
# 23  Breakfast                NA                  NA
# 24      Meats                NA                  NA
# 25      Candy                NA                  NA
# 26         NA                NA              Target
# 27         NA                NA                Aldi
# 28         NA                NA                Aldi
# 29     Cheese                NA                  NA
# 30      Meats                NA                  NA
# 31         NA                NA  Albertsons/Safeway
# 32         NA      Shelf Stable                  NA
# 33      Candy                NA                  NA
# 34  Breakfast                NA                  NA
# 35         NA                NA              Publix
# 36         NA           Ketchup                  NA
# 37     Cheese                NA                  NA
# 38         NA         Cold Cuts                  NA
# 39         NA           Gelatin                  NA
# 40         NA                NA             Walmart
# 41         NA                NA               Ahold
# 42         NA           Ketchup                  NA
# 43         NA                NA              Publix
# 44         NA                NA              Target
# 45         NA                NA                Aldi
# 46     Sauces                NA                  NA
# 47     Cheese                NA                  NA
# 48      Candy                NA                  NA
# 49         NA                NA             Walmart
#
#                                                   Entities
# 0                  Max Shipment:Task || Candy:Category ||
# 1                     Top Line:Task || Sauces:Category ||
# 2                   Net sales:Task || Tea:Sub_Category ||
# 3                Top Line:Task || Ketchup:Sub_Category ||
# 4                Revenue:Task || Hot Dogs:Sub_Category ||
# 5                   Bottom Line:Task || Candy:Category ||
# 6          Revenue:Task || Albertsons/Safeway:Customer ||
# 7                      Top Line:Task || UNIFI:Customer ||
# 8                       Revenue:Task || Meats:Category ||
# 9                      Revenue:Task || Cheese:Category ||
# 10                  Gross Sales:Task || Meats:Category ||
# 11                Bottom Line:Task || Walmart:Customer ||
# 12                 Max Shipment:Task || Ahold:Customer ||
# 13                   Net sales:Task || Cheese:Category ||
# 14                    Revenue:Task || Tea:Sub_Category ||
# 15                      Count:Task || Walmart:Customer ||
# 16                     Top Line:Task || Candy:Category ||
# 17               Bottom Line:Task || Hard:Sub_Category ||
# 18                Max Shipment:Task || Cheese:Category ||
# 19           Net sales:Task || Dollar General:Customer ||
# 20        Top Line:Task || Natural Cheese:Sub_Category ||
# 21                   Net sales:Task || Cheese:Category ||
# 22  Max Shipment:Task || Processed Cheese:Sub_Category ||
# 23             Max Shipment:Task || Breakfast:Category ||
# 24                        Count:Task || Meats:Category ||
# 25                      Revenue:Task || Candy:Category ||
# 26                     Revenue:Task || Target:Customer ||
# 27                  Max Shipment:Task || Aldi:Customer ||
# 28                       Revenue:Task || Aldi:Customer ||
# 29                   Net sales:Task || Cheese:Category ||
# 30                 Max Shipment:Task || Meats:Category ||
# 31     Bottom Line:Task || Albertsons/Safeway:Customer ||
# 32       Gross Sales:Task || Shelf Stable:Sub_Category ||
# 33                    Net sales:Task || Candy:Category ||
# 34                    Count:Task || Breakfast:Category ||
# 35                    Top Line:Task || Publix:Customer ||
# 36               Top Line:Task || Ketchup:Sub_Category ||
# 37                 Gross Sales:Task || Cheese:Category ||
# 38              Revenue:Task || Cold Cuts:Sub_Category ||
# 39                Revenue:Task || Gelatin:Sub_Category ||
# 40                      Count:Task || Walmart:Customer ||
# 41                  Bottom Line:Task || Ahold:Customer ||
# 42               Top Line:Task || Ketchup:Sub_Category ||
# 43                     Revenue:Task || Publix:Customer ||
# 44                     Revenue:Task || Target:Customer ||
# 45                   Gross Sales:Task || Aldi:Customer ||
# 46                 Gross Sales:Task || Sauces:Category ||
# 47                     Revenue:Task || Cheese:Category ||
# 48                  Gross Sales:Task || Candy:Category ||
# 49                  Net sales:Task || Walmart:Customer ||
